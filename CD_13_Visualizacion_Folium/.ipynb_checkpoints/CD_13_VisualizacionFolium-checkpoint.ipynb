# %% [markdown]
# <!--Información del curso-->
# <img align="left" style="padding-right:10px;" src="figuras/logo_ciencia_datos.png">

# %% [markdown]
# <center><h2 style="font-size:2em;color:#840700">   Análisis exploratorio con Folium  </h4></center>

# %% [markdown]
# <br><center><h1 style="font-size:2em;color:#2467C0"> Visualización geoespacial con  Folium </h1></center>
# <table>
# <col width="550">
# <col width="450">
# <tr>
# <td><img src="figuras/MapaMerida.png" align="middle" style="width:550px"/></td>
# <td>
#
#
# Folium (https://python-visualization.github.io/folium/) es una de las librerías más asequibles para análisis y representación geoespacial, por la sencillez de la sintaxis.
#
#
# Una de las características que más atrae es que no necesita convertir el DataFrame en un GeoDataFrame. Solo teniendo una serie con la latitud y otra serie con la longitud del punto espacial, es suficiente para que Folium lo represente en un mapa.
#
# </td>
# </tr>
# </table>

# %% [markdown]
# # Folium

# %% [markdown]
# _**Folium**_ es una poderosa biblioteca de visualización de datos en Python que se creó principalmente para ayudar a visualizar datos *geoespaciales*. Con Folium, se puede crear un mapa de cualquier lugar del mundo siempre que se conozcan sus valores de *latitud* y *longitud*. Además, los mapas creados por _**Folium**_ son de naturaleza interactiva, por lo que se puede acercar y alejar después de renderizar el mapa, lo cual es una característica muy útil.

# %% [markdown]
# # Configuración inicial

# %% [markdown]
# Folium proporciona la clase ``folium.Map()`` que toma el parámetro de ubicación en términos de latitud y longitud, para generar un mapa a su alrededor. Entonces, tracemos un mapa de la ciudad de Merida con latitud y longitud como _21.0530 y -89.6332_ respectivamente:

# %%
import folium
mapa = folium.Map(location=[21.0530, -89.6332])
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e3395cce41ea7b7fad37f27b7dac6db1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e3395cce41ea7b7fad37f27b7dac6db1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_e3395cce41ea7b7fad37f27b7dac6db1 = L.map(
#                 &quot;map_e3395cce41ea7b7fad37f27b7dac6db1&quot;,
#                 {
#                     center: [21.053, -89.6332],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ff7215edb2f553ac5ca6cfe6766c6ac5 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e3395cce41ea7b7fad37f27b7dac6db1);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Puede ver que estos mapas son interactivos. Puede acercar y alejar haciendo clic en los botones positivo y negativo en la esquina superior izquierda del mapa. También puede arrastrar el mapa y ver diferentes regiones.
#
# A continuación, pasemos al segundo problema y cambiemos el nivel de zoom. De forma predeterminada, puede acercar y alejar tanto como desee. Además, el nivel de zoom inicial se fija en 10 (el mapa se traza con un zoom de 10x).  Para hacer esto, Folium nos da tres parámetros: ``zoom_start``, ``min_zoom`` y ``max_zoom``.
#
# Entonces, tracemos nuevamente el mapa de Mérida pero esta vez de con un nivel de zoom desde el inicio:

# %%
mapa = folium.Map(location=[20.9785, -89.6332],zoom_start=12)
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c552498fd10fdc73f9ca5210d9ba58f5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c552498fd10fdc73f9ca5210d9ba58f5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_c552498fd10fdc73f9ca5210d9ba58f5 = L.map(
#                 &quot;map_c552498fd10fdc73f9ca5210d9ba58f5&quot;,
#                 {
#                     center: [20.9785, -89.6332],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_01b831c11117ebd5c61c6374d215e908 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c552498fd10fdc73f9ca5210d9ba58f5);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Ahora tracemos nuevamente el mapa de Mérida  con un nivel de zoom restringido:

# %%
mapa = folium.Map(location=[20.9785, -89.6332],zoom_start=12,min_zoom=10,max_zoom=13)
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_71e7d3572a0115b099e8476edb8ea9e7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_71e7d3572a0115b099e8476edb8ea9e7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_71e7d3572a0115b099e8476edb8ea9e7 = L.map(
#                 &quot;map_71e7d3572a0115b099e8476edb8ea9e7&quot;,
#                 {
#                     center: [20.9785, -89.6332],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ad58ec4734e69bf580aaf158412f61a5 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 13, &quot;maxZoom&quot;: 13, &quot;minZoom&quot;: 10, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_71e7d3572a0115b099e8476edb8ea9e7);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Marcadores en el mapa

# %% [markdown]
# Los marcadores son los elementos que se utilizan para marcar una ubicación en un mapa. Por ejemplo, cuando utiliza _Google Maps_ para la navegación, su ubicación se marca con un marcador y su destino se marca con otro marcador. Los marcadores se encuentran entre los elementos más importantes y útiles de un mapa.
#
# _**Folium**_ proporciona una clase  ``folium.Marker ()``  para trazar marcadores en un mapa. Simplemente pase la latitud y la longitud de la ubicación, mencione la ventana emergente y la información sobre herramientas y agréguela al mapa.
#
# Agregar marcadores es un proceso de dos pasos. Primero, debe crear un mapa base en el que se colocarán sus marcadores, y luego agregar sus marcadores. En el siguiente ejemplo se muestra su implementación junto con algunas opciones extras de visualización:

# %%
# Mapa de base
mapa=folium.Map(location=[20.9785, -89.6332],zoom_start=12)
# Agregar marcadores al mapa
folium.Marker(location=[21.04829, -89.64025],popup='FIUADY').add_to(mapa)
folium.Marker(location=[20.96972, -89.62272],popup='<strong>Edificio Central UADY</strong>',tooltip='<strong>Click here to see Popup</strong>').add_to(mapa)
folium.Marker(location=[20.94167,-89.59466],popup='<h3 style="color:green;">Estadio Kukulc&aacute;n</h3>',tooltip='<strong>Click here to see Popup</strong>').add_to(mapa)

mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2ed86b69931f0120f75bcbe05128e510 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2ed86b69931f0120f75bcbe05128e510&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_2ed86b69931f0120f75bcbe05128e510 = L.map(
#                 &quot;map_2ed86b69931f0120f75bcbe05128e510&quot;,
#                 {
#                     center: [20.9785, -89.6332],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bc35c16bb88b089e2a5464185a858832 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2ed86b69931f0120f75bcbe05128e510);
#
#
#             var marker_0f6d0c18fb2f9916d194cc4e94eb4a51 = L.marker(
#                 [21.04829, -89.64025],
#                 {}
#             ).addTo(map_2ed86b69931f0120f75bcbe05128e510);
#
#
#         var popup_5d27558c658994486a58bcb2541316e5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0c660d92c48535655015001dd886c15c = $(`&lt;div id=&quot;html_0c660d92c48535655015001dd886c15c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;FIUADY&lt;/div&gt;`)[0];
#                 popup_5d27558c658994486a58bcb2541316e5.setContent(html_0c660d92c48535655015001dd886c15c);
#
#
#
#         marker_0f6d0c18fb2f9916d194cc4e94eb4a51.bindPopup(popup_5d27558c658994486a58bcb2541316e5)
#         ;
#
#
#
#
#             var marker_f85b837fe861b5299cc96a367204bd13 = L.marker(
#                 [20.96972, -89.62272],
#                 {}
#             ).addTo(map_2ed86b69931f0120f75bcbe05128e510);
#
#
#         var popup_3b1b374181235b948e7e710b7678822e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bc58edc7d49a4fc5df669875580461d4 = $(`&lt;div id=&quot;html_bc58edc7d49a4fc5df669875580461d4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;Edificio Central UADY&lt;/strong&gt;&lt;/div&gt;`)[0];
#                 popup_3b1b374181235b948e7e710b7678822e.setContent(html_bc58edc7d49a4fc5df669875580461d4);
#
#
#
#         marker_f85b837fe861b5299cc96a367204bd13.bindPopup(popup_3b1b374181235b948e7e710b7678822e)
#         ;
#
#
#
#
#             marker_f85b837fe861b5299cc96a367204bd13.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;strong&gt;Click here to see Popup&lt;/strong&gt;
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_1fa83c6205596cdc8ddc20b6b95c5a53 = L.marker(
#                 [20.94167, -89.59466],
#                 {}
#             ).addTo(map_2ed86b69931f0120f75bcbe05128e510);
#
#
#         var popup_5e462194cad088fcc1cbc7899ee5ea80 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_09b212e33fc06d2ba571d1f88bd32a2c = $(`&lt;div id=&quot;html_09b212e33fc06d2ba571d1f88bd32a2c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;h3 style=&quot;color:green;&quot;&gt;Estadio Kukulc&amp;aacute;n&lt;/h3&gt;&lt;/div&gt;`)[0];
#                 popup_5e462194cad088fcc1cbc7899ee5ea80.setContent(html_09b212e33fc06d2ba571d1f88bd32a2c);
#
#
#
#         marker_1fa83c6205596cdc8ddc20b6b95c5a53.bindPopup(popup_5e462194cad088fcc1cbc7899ee5ea80)
#         ;
#
#
#
#
#             marker_1fa83c6205596cdc8ddc20b6b95c5a53.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;strong&gt;Click here to see Popup&lt;/strong&gt;
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# En el mapa anteriorcuando pasa el cursor sobre un marcador el texto que aparece se conoce como ``tooltip`` (información sobre herramienta)  y el texto cuando hace clic en un marcador se conoce como una ``popup`` (ventana emergente). Si se observa detenidamente, se ha  personalizado la información  de los marcadores 2 y 3.

# %% [markdown]
# ## Marcadores personalizados

# %% [markdown]
# Para mejorar la visualización puede cambiar el icono del marcador, Folium proporciona la clase ``folium.Icon()`` que se puede utilizar para crear iconos personalizados para marcadores. Puede elegir iconos entre una amplia gama de opciones.
#
# ``Icon()`` toma tres argumentos: color, prefijo e icono. El color se utiliza para cambiar el color del marcador, el prefijo se utiliza para seleccionar el proveedor de iconos (prefix='fa' para https://fontawesome.com/icons?d=gallery&m=free y  prefix='glyphicon' para  https://getbootstrap.com/docs/3.3/components/) y el icono se utiliza para seleccionar el nombre del icono.

# %%
# Mapa de base
mapa=folium.Map(location=[20.9785, -89.6332],zoom_start=12)
# Agregar marcadores al mapa
folium.Marker(location=[21.04829, -89.64025], popup='FIUADY',  
             icon=folium.Icon(color='red',icon='none') ).add_to(mapa)

folium.Marker(location=[20.96972, -89.62272],popup='<strong>Edificio Central UADY</strong>',
              tooltip='<strong>Click here to see Popup</strong>',
              icon=folium.Icon(color='green',prefix='fa',icon='crosshairs')     ).add_to(mapa)


folium.Marker(location=[20.94167,-89.59466],popup='<h3 style="color:green;">Estadio Kukulc&aacute;n</h3>',
              tooltip='<strong>Click here to see Popup</strong>',
              icon=folium.Icon(color='purple',prefix='glyphicon',icon='camera')   ).add_to(mapa)

mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7b7181b0afea6195a4cd9c109916a8b0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7b7181b0afea6195a4cd9c109916a8b0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_7b7181b0afea6195a4cd9c109916a8b0 = L.map(
#                 &quot;map_7b7181b0afea6195a4cd9c109916a8b0&quot;,
#                 {
#                     center: [20.9785, -89.6332],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d0eeecff2bcf4edc55754aa8929ac23f = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7b7181b0afea6195a4cd9c109916a8b0);
#
#
#             var marker_7680a5d6488d4ff5090997488dc046c3 = L.marker(
#                 [21.04829, -89.64025],
#                 {}
#             ).addTo(map_7b7181b0afea6195a4cd9c109916a8b0);
#
#
#             var icon_cf424418662783af39de7de3501803c9 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;none&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7680a5d6488d4ff5090997488dc046c3.setIcon(icon_cf424418662783af39de7de3501803c9);
#
#
#         var popup_8c86cd519e66bed7b85ce2d25ff55e6c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_425489f80fee8b832d1bb1df6d433a44 = $(`&lt;div id=&quot;html_425489f80fee8b832d1bb1df6d433a44&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;FIUADY&lt;/div&gt;`)[0];
#                 popup_8c86cd519e66bed7b85ce2d25ff55e6c.setContent(html_425489f80fee8b832d1bb1df6d433a44);
#
#
#
#         marker_7680a5d6488d4ff5090997488dc046c3.bindPopup(popup_8c86cd519e66bed7b85ce2d25ff55e6c)
#         ;
#
#
#
#
#             var marker_9f309547e6bd9bbec175e16e42b818e2 = L.marker(
#                 [20.96972, -89.62272],
#                 {}
#             ).addTo(map_7b7181b0afea6195a4cd9c109916a8b0);
#
#
#             var icon_615cdb885bf2f8ea5b8487000c625a6b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;crosshairs&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_9f309547e6bd9bbec175e16e42b818e2.setIcon(icon_615cdb885bf2f8ea5b8487000c625a6b);
#
#
#         var popup_ada6ea1155120b70c96fabc54fed064c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d29122d73579d3938eca1df15ffb1fa7 = $(`&lt;div id=&quot;html_d29122d73579d3938eca1df15ffb1fa7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;Edificio Central UADY&lt;/strong&gt;&lt;/div&gt;`)[0];
#                 popup_ada6ea1155120b70c96fabc54fed064c.setContent(html_d29122d73579d3938eca1df15ffb1fa7);
#
#
#
#         marker_9f309547e6bd9bbec175e16e42b818e2.bindPopup(popup_ada6ea1155120b70c96fabc54fed064c)
#         ;
#
#
#
#
#             marker_9f309547e6bd9bbec175e16e42b818e2.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;strong&gt;Click here to see Popup&lt;/strong&gt;
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_82f9a06c2d46cf0640d0efb6cd652b3e = L.marker(
#                 [20.94167, -89.59466],
#                 {}
#             ).addTo(map_7b7181b0afea6195a4cd9c109916a8b0);
#
#
#             var icon_402979bf497347365feec78c7a1d13d6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;camera&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;purple&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_82f9a06c2d46cf0640d0efb6cd652b3e.setIcon(icon_402979bf497347365feec78c7a1d13d6);
#
#
#         var popup_be57f7a9332fea2281ed760272737a3d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a88fc9fe7631373042a53d778abbd178 = $(`&lt;div id=&quot;html_a88fc9fe7631373042a53d778abbd178&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;h3 style=&quot;color:green;&quot;&gt;Estadio Kukulc&amp;aacute;n&lt;/h3&gt;&lt;/div&gt;`)[0];
#                 popup_be57f7a9332fea2281ed760272737a3d.setContent(html_a88fc9fe7631373042a53d778abbd178);
#
#
#
#         marker_82f9a06c2d46cf0640d0efb6cd652b3e.bindPopup(popup_be57f7a9332fea2281ed760272737a3d)
#         ;
#
#
#
#
#             marker_82f9a06c2d46cf0640d0efb6cd652b3e.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;strong&gt;Click here to see Popup&lt;/stro

# %% [markdown]
# ## Marcadores  tipo circunferencia

# %% [markdown]
# Se realiza mediante la función ``folium.Circle``. Cada circunferencia tiene un tamaño relacionado con un valor específico, a través del parametro ``radius`` (metros).

# %%
mapa=folium.Map(location=[20.9785, -89.6332],zoom_start=12 )
# Agregar marcadores al mapa
folium.Marker(location=[21.04829, -89.64025], popup='FIUADY',  
             icon=folium.Icon(color='red',icon='none') ).add_to(mapa)

folium.Marker(location=[20.96972, -89.62272],popup='<strong>Edificio Central UADY</strong>',
              tooltip='<strong>Click here to see Popup</strong>',
              icon=folium.Icon(color='green',prefix='fa',icon='crosshairs')     ).add_to(mapa)


folium.Marker(location=[20.94167,-89.59466],popup='<h3 style="color:green;">Estadio Kukulc&aacute;n</h3>',
              tooltip='<strong>Click here to see Popup</strong>',
              icon=folium.Icon(color='purple',prefix='glyphicon',icon='camera')   ).add_to(mapa)


folium.Circle(
    radius=500,
    location=[20.956972, -89.62272],
    popup='Sur',
    color='crimson',
    fill=False,
).add_to(mapa)

folium.Circle(
    location=[20.996972, -89.62272],
    radius=1500,
    popup='Norte',
    color='#3186cc',
    fill=True,
    fill_color='#3186cc'
).add_to(mapa)


mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f83870f58694e86881848f46ee887fea {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f83870f58694e86881848f46ee887fea&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_f83870f58694e86881848f46ee887fea = L.map(
#                 &quot;map_f83870f58694e86881848f46ee887fea&quot;,
#                 {
#                     center: [20.9785, -89.6332],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3d6ba7bc601a3d1e2d0c7c98a03e129f = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f83870f58694e86881848f46ee887fea);
#
#
#             var marker_c0f30c1a4116db4b2952b03d7f2aa084 = L.marker(
#                 [21.04829, -89.64025],
#                 {}
#             ).addTo(map_f83870f58694e86881848f46ee887fea);
#
#
#             var icon_3d91e1011f40eb36a0e711489da8baf9 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;none&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c0f30c1a4116db4b2952b03d7f2aa084.setIcon(icon_3d91e1011f40eb36a0e711489da8baf9);
#
#
#         var popup_337a42ec7efc1a0c2e3e602cc7b162b2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_529418bde3becca06c807a64d54f7d61 = $(`&lt;div id=&quot;html_529418bde3becca06c807a64d54f7d61&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;FIUADY&lt;/div&gt;`)[0];
#                 popup_337a42ec7efc1a0c2e3e602cc7b162b2.setContent(html_529418bde3becca06c807a64d54f7d61);
#
#
#
#         marker_c0f30c1a4116db4b2952b03d7f2aa084.bindPopup(popup_337a42ec7efc1a0c2e3e602cc7b162b2)
#         ;
#
#
#
#
#             var marker_ab45b9529706472c10e6b768a38f580c = L.marker(
#                 [20.96972, -89.62272],
#                 {}
#             ).addTo(map_f83870f58694e86881848f46ee887fea);
#
#
#             var icon_238b755f25e305d4d09b640f8739e7a1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;crosshairs&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_ab45b9529706472c10e6b768a38f580c.setIcon(icon_238b755f25e305d4d09b640f8739e7a1);
#
#
#         var popup_f2fb086558781f09fb9c243f13a867c7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_edff636b44a0d04f7e94fa72d0914b80 = $(`&lt;div id=&quot;html_edff636b44a0d04f7e94fa72d0914b80&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;Edificio Central UADY&lt;/strong&gt;&lt;/div&gt;`)[0];
#                 popup_f2fb086558781f09fb9c243f13a867c7.setContent(html_edff636b44a0d04f7e94fa72d0914b80);
#
#
#
#         marker_ab45b9529706472c10e6b768a38f580c.bindPopup(popup_f2fb086558781f09fb9c243f13a867c7)
#         ;
#
#
#
#
#             marker_ab45b9529706472c10e6b768a38f580c.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;strong&gt;Click here to see Popup&lt;/strong&gt;
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_3604edba0d62d07a3581c5afa62220b7 = L.marker(
#                 [20.94167, -89.59466],
#                 {}
#             ).addTo(map_f83870f58694e86881848f46ee887fea);
#
#
#             var icon_bd9468409505c833fffde9589ab3ba28 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;camera&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;purple&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_3604edba0d62d07a3581c5afa62220b7.setIcon(icon_bd9468409505c833fffde9589ab3ba28);
#
#
#         var popup_925f32fa5b732bc740508ccb3dc6a2f6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5892b56f0a6ba8b5df5f1f987b223a38 = $(`&lt;div id=&quot;html_5892b56f0a6ba8b5df5f1f987b223a38&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;h3 style=&quot;color:green;&quot;&gt;Estadio Kukulc&amp;aacute;n&lt;/h3&gt;&lt;/div&gt;`)[0];
#                 popup_925f32fa5b732bc740508ccb3dc6a2f6.setContent(html_5892b56f0a6ba8b5df5f1f987b223a38);
#
#
#
#         marker_3604edba0d62d07a3581c5afa62220b7.bindPopup(popup_925f32fa5b732bc740508ccb3dc6a2f6)
#         ;
#
#
#
#
#             marker_3604edba0d62d07a3581c5afa62220b7.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;strong&gt;Click here to see Popup&lt;/stro

# %% [markdown]
# # Estilo del mapa

# %% [markdown]
# El estilo predeterminado se encuentra con la opción ``OpenStreetMap``, pero tambien cuenta con ``Stamen Terrain``, ``Stamen Toner``, ``Mapbox Bright``,  ``Mapbox Control Room`` y otros (https://deparkes.co.uk/2016/06/10/folium-map-tiles/).

# %% [markdown]
# ###  Stamen Toner

# %%
# Mapa de base
# Mapa de base
mapa=folium.Map(location=[20.9785, -89.6332],zoom_start=12,  tiles ='Stamen Toner')
# Agregar marcadores al mapa
folium.Marker(location=[21.04829, -89.64025], popup='FIUADY',  
             icon=folium.Icon(color='red',icon='none') ).add_to(mapa)

folium.Marker(location=[20.96972, -89.62272],popup='<strong>Edificio Central UADY</strong>',
              tooltip='<strong>Click here to see Popup</strong>',
              icon=folium.Icon(color='green',prefix='fa',icon='crosshairs')     ).add_to(mapa)


folium.Marker(location=[20.94167,-89.59466],popup='<h3 style="color:green;">Estadio Kukulc&aacute;n</h3>',
              tooltip='<strong>Click here to see Popup</strong>',
              icon=folium.Icon(color='purple',prefix='glyphicon',icon='camera')   ).add_to(mapa)

folium.Circle(
    radius=500,
    location=[20.956972, -89.62272],
    popup='Sur',
    color='crimson',
    fill=False,
).add_to(mapa)

folium.Circle(
    location=[20.996972, -89.62272],
    radius=1500,
    popup='Norte',
    color='#3186cc',
    fill=True,
    fill_color='#3186cc'
).add_to(mapa)

mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3a1c0760438f9f7f7d94b4362a23d858 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3a1c0760438f9f7f7d94b4362a23d858&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_3a1c0760438f9f7f7d94b4362a23d858 = L.map(
#                 &quot;map_3a1c0760438f9f7f7d94b4362a23d858&quot;,
#                 {
#                     center: [20.9785, -89.6332],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d1e51a6cecf2c20ee7addec6ddbac377 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3a1c0760438f9f7f7d94b4362a23d858);
#
#
#             var marker_c341dd6b23cf6dc66f02b6553c5db443 = L.marker(
#                 [21.04829, -89.64025],
#                 {}
#             ).addTo(map_3a1c0760438f9f7f7d94b4362a23d858);
#
#
#             var icon_ae8c8df26650837f1661485150e4863a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;none&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c341dd6b23cf6dc66f02b6553c5db443.setIcon(icon_ae8c8df26650837f1661485150e4863a);
#
#
#         var popup_2cee9dcebe0cc0807242df56a438a4f5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c171fa438c5ec776526c0884e3ac5383 = $(`&lt;div id=&quot;html_c171fa438c5ec776526c0884e3ac5383&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;FIUADY&lt;/div&gt;`)[0];
#                 popup_2cee9dcebe0cc0807242df56a438a4f5.setContent(html_c171fa438c5ec776526c0884e3ac5383);
#
#
#
#         marker_c341dd6b23cf6dc66f02b6553c5db443.bindPopup(popup_2cee9dcebe0cc0807242df56a438a4f5)
#         ;
#
#
#
#
#             var marker_4fe6b73f1ddcce2b86af920ad68df375 = L.marker(
#                 [20.96972, -89.62272],
#                 {}
#             ).addTo(map_3a1c0760438f9f7f7d94b4362a23d858);
#
#
#             var icon_7acbffd7b8de852c7e6af21add356769 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;crosshairs&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_4fe6b73f1ddcce2b86af920ad68df375.setIcon(icon_7acbffd7b8de852c7e6af21add356769);
#
#
#         var popup_3ecd67f75118fdb7f8040e1d0729a17a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bc9b4aa5ef136aecf876ff7af44352ca = $(`&lt;div id=&quot;html_bc9b4aa5ef136aecf876ff7af44352ca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;Edificio Central UADY&lt;/strong&gt;&lt;/div&gt;`)[0];
#                 popup_3ecd67f75118fdb7f8040e1d0729a17a.setContent(html_bc9b4aa5ef136aecf876ff7af44352ca);
#
#
#
#         marker_4fe6b73f1ddcce2b86af920ad68df375.bindPopup(popup_3ecd67f75118fdb7f8040e1d0729a17a)
#         ;
#
#
#
#
#             marker_4fe6b73f1ddcce2b86af920ad68df375.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;strong&gt;Click here to see Popup&lt;/strong&gt;
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_47dde0e72c298876489dced519ca9811 = L.marker(
#                 [20.94167, -89.59466],
#                 {}
#             ).addTo(map_3a1c0760438f9f7f7d94b4362a23d858);
#
#
#             var icon_4f6c500fbf8f56f03a36d0732673ec6a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;camera&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;purple&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_47dde0e72c298876489dced519ca9811.setIcon(icon_4f6c500fbf8f56f03a36d0732673ec6a);
#
#
#         var popup_d2e087b559a89ab8713daa2fff04d123 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_78bf5c543b14d89dabb5da0a7d851a66 = $(`&lt;div id=&quot;html_78bf5c543b14d89dabb5da0a7d851a66&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;h3 style=&quot;color:green;&quot;&gt;Estadio Kukulc&amp;aacute;n&lt;/h3&gt;&lt;/div&gt;`)[0];
#                 popup_d2e087b559a89ab8713daa2fff04d123.setContent(html_78bf5c543b14d89dabb5da0a7d851a66);
#
#
#
#         marker_47dde0e72c298876489dced519ca9811.bindPopup(popup_d2e087b559a89a

# %% [markdown]
# ### Mapbox Bright

# %%
# Mapa de base
# Mapa de base
mapa=folium.Map(location=[20.9785, -89.6332],zoom_start=12,  tiles ='Stamen Terrain')
# Agregar marcadores al mapa
folium.Marker(location=[21.04829, -89.64025], popup='FIUADY',  
             icon=folium.Icon(color='red',icon='none') ).add_to(mapa)

folium.Marker(location=[20.96972, -89.62272],popup='<strong>Edificio Central UADY</strong>',
              tooltip='<strong>Click here to see Popup</strong>',
              icon=folium.Icon(color='green',prefix='fa',icon='crosshairs')     ).add_to(mapa)


folium.Marker(location=[20.94167,-89.59466],popup='<h3 style="color:green;">Estadio Kukulc&aacute;n</h3>',
              tooltip='<strong>Click here to see Popup</strong>',
              icon=folium.Icon(color='purple',prefix='glyphicon',icon='camera')   ).add_to(mapa)

folium.Circle(
    radius=500,
    location=[20.956972, -89.62272],
    popup='Sur',
    color='crimson',
    fill=False,
).add_to(mapa)

folium.Circle(
    location=[20.996972, -89.62272],
    radius=1500,
    popup='Norte',
    color='#3186cc',
    fill=True,
    fill_color='#3186cc'
).add_to(mapa)

mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6f27dfd803c7eb18f68af88d891c9c63 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6f27dfd803c7eb18f68af88d891c9c63&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_6f27dfd803c7eb18f68af88d891c9c63 = L.map(
#                 &quot;map_6f27dfd803c7eb18f68af88d891c9c63&quot;,
#                 {
#                     center: [20.9785, -89.6332],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_05b23932b6fd8598d097eebc55ca8142 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6f27dfd803c7eb18f68af88d891c9c63);
#
#
#             var marker_c9c0ec9f93b6b2230cb51dbca2581b11 = L.marker(
#                 [21.04829, -89.64025],
#                 {}
#             ).addTo(map_6f27dfd803c7eb18f68af88d891c9c63);
#
#
#             var icon_e351329aa47ec54999b184a4db2a04ec = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;none&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c9c0ec9f93b6b2230cb51dbca2581b11.setIcon(icon_e351329aa47ec54999b184a4db2a04ec);
#
#
#         var popup_1203ad9cc8242905310d243e553bae74 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_be385e9b837115f279879b4454baf351 = $(`&lt;div id=&quot;html_be385e9b837115f279879b4454baf351&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;FIUADY&lt;/div&gt;`)[0];
#                 popup_1203ad9cc8242905310d243e553bae74.setContent(html_be385e9b837115f279879b4454baf351);
#
#
#
#         marker_c9c0ec9f93b6b2230cb51dbca2581b11.bindPopup(popup_1203ad9cc8242905310d243e553bae74)
#         ;
#
#
#
#
#             var marker_f4415a7102d5b3e4c0d69a0188333f93 = L.marker(
#                 [20.96972, -89.62272],
#                 {}
#             ).addTo(map_6f27dfd803c7eb18f68af88d891c9c63);
#
#
#             var icon_805edb390490064c11359bfeccb777c9 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;crosshairs&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_f4415a7102d5b3e4c0d69a0188333f93.setIcon(icon_805edb390490064c11359bfeccb777c9);
#
#
#         var popup_b62d01b7ba1c40ec6225011ab4c38fd1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_291f71007be45326d56e3adfb9f5ff99 = $(`&lt;div id=&quot;html_291f71007be45326d56e3adfb9f5ff99&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;Edificio Central UADY&lt;/strong&gt;&lt;/div&gt;`)[0];
#                 popup_b62d01b7ba1c40ec6225011ab4c38fd1.setContent(html_291f71007be45326d56e3adfb9f5ff99);
#
#
#
#         marker_f4415a7102d5b3e4c0d69a0188333f93.bindPopup(popup_b62d01b7ba1c40ec6225011ab4c38fd1)
#         ;
#
#
#
#
#             marker_f4415a7102d5b3e4c0d69a0188333f93.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;strong&gt;Click here to see Popup&lt;/strong&gt;
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_12af8fbf04f29109515f4b46e7a87a4e = L.marker(
#                 [20.94167, -89.59466],
#                 {}
#             ).addTo(map_6f27dfd803c7eb18f68af88d891c9c63);
#
#
#             var icon_3af4c5a6f9378d534b265da491ebdcba = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;camera&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;purple&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_12af8fbf04f29109515f4b46e7a87a4e.setIcon(icon_3af4c5a6f9378d534b265da491ebdcba);
#
#
#         var popup_ccd7c325bd228d3b8b8bf44f4035c412 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_621151513341110e59bb60cd6bce052c = $(`&lt;div id=&quot;html_621151513341110e59bb60cd6bce052c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;h3 style=&quot;color:green;&quot;&gt;Estadio Kukulc&amp;aacute;n&lt;/h3&gt;&lt;/div&gt;`)[0];
#                 popup_ccd7c325bd228d3b8b8bf44f4035c412.setContent(html_621151513341110e59bb60cd6bce052c);
#
#
#
#         marker_12af8fbf04f29109515f4b46e7a87a4e.bindPopup(popup_c
