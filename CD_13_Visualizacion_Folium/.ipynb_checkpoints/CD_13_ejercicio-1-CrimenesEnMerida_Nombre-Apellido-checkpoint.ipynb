# %% [markdown]
# <!--Información del curso-->
# <img align="left" style="padding-right:10px;" src="figuras/logo_ciencia_datos.png">

# %% [markdown]
# <br><br><center><h1 style="font-size:2em;color:#2467C0"> Ejericicio 1: Crimenes en la ciudad de Mérida (Ficticio)  </h1></center>
# <br>
# <table>
# <col width="550">
# <col width="450">
# <tr>
# <td><img src="figuras/policia.jpeg" align="middle" style="width:550px"/></td>
# <td>
#
# La Fiscalía General del Estado informó que al día en promedio en Yucatán se registran ocho robos en sus diferentes modalidades, aunque la mayor parte de ellos, cerca del 80 por ciento, ocurre en Mérida.
#
# En esta ciudad, las zonas de mayor incidencia son el Poniente, Sur y Centro.
#
# Aunque los casos más sonados, de mayor cuantía en cuanto al botín y que han llamado la atención de los medios, se dijo que se han registrado en el Norte.
#
# https://www.yucatan.com.mx/merida/merida-el-blanco-principal-de-los-robos
#
#  <br>
# </td>
# </tr>
# </table>

# %% [markdown]
# # Ejercicio

# %% [markdown]
# <div class="alert alert-success">
#
# Con los datos del archivo "asaltos_yucatan.csv", mostrar en un mapa la ubicación de los delitos en Mérida, de ser posible muestre como _popup_ la categoría.
#
#
# </div>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import folium

# %%
#Cargar el archivo datos/asaltos_yucatan.csv en un DataFrame llamado data
# si es necesario usar la opcion encoding = "ISO-8859-1"
data = pd.read_csv('datos/asaltos_yucatan.csv', encoding = "ISO-8859-1")

# %%
#Mostrar las primeras filas del DataFrame data
data.head()
# Out:
#    NumInc  Categoria              Descripcion   Ciudad          Direccion  \
# 0       1     asalto  robo objetos personales  Tizimín             Centro
# 1       2     asalto  robo objetos personales   Mérida         Calle 53-F
# 2       3     asalto  robo objetos personales   Mérida   Calle 53 791-803
# 3       4     asalto  robo objetos personales   Mérida   Calle 49 808-796
# 4       5  robo casa     robo casa habitacion   Mérida  Calle 51A 784-780
#
#          lat       long
# 0  21.142586 -88.147633
# 1  21.074071 -89.666229
# 2  21.077830 -89.655865
# 3  21.001845 -89.713986
# 4  21.000559 -89.712173

# %%
data['Categoria'].unique()
# Out:
# array(['asalto', 'robo casa'], dtype=object)

# %%
data = data[data['Ciudad'] == 'Mérida']

# %%
# Creando el mapa
mapa = folium.Map(location=[20.9785, -89.6332],zoom_start=12)
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_50fce58375d6084c7483d9cfd5059ce7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_50fce58375d6084c7483d9cfd5059ce7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_50fce58375d6084c7483d9cfd5059ce7 = L.map(
#                 &quot;map_50fce58375d6084c7483d9cfd5059ce7&quot;,
#                 {
#                     center: [20.9785, -89.6332],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5ac625d6d19bc14608255c7bb0f83eff = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_50fce58375d6084c7483d9cfd5059ce7);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
mapa = folium.Map(location=[20.9785, -89.6332],zoom_start=11)
for i in range(len(data)):
    delito = data.iloc[i]
    color = 'blue'
    if delito['Categoria'] == 'asalto':
        color = 'red'
    folium.Marker(location=[delito['lat'], delito['long']],popup=f'<h3 style="color:{color};">' + delito['Categoria'] + '</h3>',
              tooltip='<strong>Click here to see Popup</strong>', icon=folium.Icon(color=color)).add_to(mapa)

mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d17c876c6b5ec4f363c27744a7a31da1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d17c876c6b5ec4f363c27744a7a31da1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d17c876c6b5ec4f363c27744a7a31da1 = L.map(
#                 &quot;map_d17c876c6b5ec4f363c27744a7a31da1&quot;,
#                 {
#                     center: [20.9785, -89.6332],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_68ad42a3a25dba5968fffe13a97ea61f = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d17c876c6b5ec4f363c27744a7a31da1);
#
#
#             var marker_c09d5f39123ca42617348d135e3c4ecd = L.marker(
#                 [21.074071, -89.666229],
#                 {}
#             ).addTo(map_d17c876c6b5ec4f363c27744a7a31da1);
#
#
#             var icon_50ddb93ea34729f87b7252b76412ede8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c09d5f39123ca42617348d135e3c4ecd.setIcon(icon_50ddb93ea34729f87b7252b76412ede8);
#
#
#         var popup_9e2a1ad14190fef3a44314d12fa2ac60 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d4b50f72d8eded47bfa7b04fb07d8e2f = $(`&lt;div id=&quot;html_d4b50f72d8eded47bfa7b04fb07d8e2f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;h3 style=&quot;color:red;&quot;&gt;asalto&lt;/h3&gt;&lt;/div&gt;`)[0];
#                 popup_9e2a1ad14190fef3a44314d12fa2ac60.setContent(html_d4b50f72d8eded47bfa7b04fb07d8e2f);
#
#
#
#         marker_c09d5f39123ca42617348d135e3c4ecd.bindPopup(popup_9e2a1ad14190fef3a44314d12fa2ac60)
#         ;
#
#
#
#
#             marker_c09d5f39123ca42617348d135e3c4ecd.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;strong&gt;Click here to see Popup&lt;/strong&gt;
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_c6165a64ce6338ab35e1c630b028be6a = L.marker(
#                 [21.07783, -89.655865],
#                 {}
#             ).addTo(map_d17c876c6b5ec4f363c27744a7a31da1);
#
#
#             var icon_845256d48809211e5e14d3473c691e5f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c6165a64ce6338ab35e1c630b028be6a.setIcon(icon_845256d48809211e5e14d3473c691e5f);
#
#
#         var popup_329fea37d00c0b7b596a99e4cf5af9ff = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d93bbb0387d4ec8a087f54c320123e5e = $(`&lt;div id=&quot;html_d93bbb0387d4ec8a087f54c320123e5e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;h3 style=&quot;color:red;&quot;&gt;asalto&lt;/h3&gt;&lt;/div&gt;`)[0];
#                 popup_329fea37d00c0b7b596a99e4cf5af9ff.setContent(html_d93bbb0387d4ec8a087f54c320123e5e);
#
#
#
#         marker_c6165a64ce6338ab35e1c630b028be6a.bindPopup(popup_329fea37d00c0b7b596a99e4cf5af9ff)
#         ;
#
#
#
#
#             marker_c6165a64ce6338ab35e1c630b028be6a.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;strong&gt;Click here to see Popup&lt;/strong&gt;
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_f5bb5032977be5103351fac761141b2c = L.marker(
#                 [21.001845, -89.713986],
#                 {}
#             ).addTo(map_d17c876c6b5ec4f363c27744a7a31da1);
#
#
#             var icon_58d4121f00aa2f5bd65ee9977609b4c1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f5bb5032977be5103351fac761141b2c.setIcon(icon_58d4121f00aa2f5bd65ee9977609b4c1);
#
#
#         var popup_e1ac12d957a99496c4ae91bac5d7fa47 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_926ffa89f48629aa0e8806e4ec29e891 = $(`&lt;div id=&quot;html_926ffa89f48629aa0e8806e4ec29e891&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;h3 style=&quot;color:red;&quot;&
