# %% [markdown]
# <!--Información del curso-->
# <img align="left" style="padding-right:10px;" src="figuras/logo_ciencia_datos.png">

# %% [markdown]
# <center><h2 style="font-size:2em;color:#840700">   Análisis exploratorio con Folium  </h4></center>

# %% [markdown]
# <br><center><h1 style="font-size:2em;color:#2467C0"> Visualización geoespacial con  Folium </h1></center>
# <table>
# <col width="550">
# <col width="450">
# <tr>
# <td><img src="figuras/MapaMerida.png" align="middle" style="width:550px"/></td>
# <td>
#
#
# Folium (https://python-visualization.github.io/folium/) es una de las librerías más asequibles para análisis y representación geoespacial, por la sencillez de la sintaxis.
#
#
# Una de las características que más atrae es que no necesita convertir el DataFrame en un GeoDataFrame. Solo teniendo una serie con la latitud y otra serie con la longitud del punto espacial, es suficiente para que Folium lo represente en un mapa.
#
# </td>
# </tr>
# </table>

# %% [markdown]
# # Folium

# %% [markdown]
# _**Folium**_ es una poderosa biblioteca de visualización de datos en Python que se creó principalmente para ayudar a visualizar datos *geoespaciales*. Con Folium, se puede crear un mapa de cualquier lugar del mundo siempre que se conozcan sus valores de *latitud* y *longitud*. Además, los mapas creados por _**Folium**_ son de naturaleza interactiva, por lo que se puede acercar y alejar después de renderizar el mapa, lo cual es una característica muy útil.

# %% [markdown]
# # Configuración inicial

# %% [markdown]
# Folium proporciona la clase ``folium.Map()`` que toma el parámetro de ubicación en términos de latitud y longitud, para generar un mapa a su alrededor. Entonces, tracemos un mapa de la ciudad de Merida con latitud y longitud como _21.0530 y -89.6332_ respectivamente:

# %%
import folium
mapa = folium.Map(location=[21.0530, -89.6332])
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_52d56568ed054423cbf638fe4742bfa8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_52d56568ed054423cbf638fe4742bfa8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_52d56568ed054423cbf638fe4742bfa8 = L.map(
#                 &quot;map_52d56568ed054423cbf638fe4742bfa8&quot;,
#                 {
#                     center: [21.053, -89.6332],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_faa13d75f34e192e54534a1d0c28826b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_52d56568ed054423cbf638fe4742bfa8);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Puede ver que estos mapas son interactivos. Puede acercar y alejar haciendo clic en los botones positivo y negativo en la esquina superior izquierda del mapa. También puede arrastrar el mapa y ver diferentes regiones.
#
# A continuación, pasemos al segundo problema y cambiemos el nivel de zoom. De forma predeterminada, puede acercar y alejar tanto como desee. Además, el nivel de zoom inicial se fija en 10 (el mapa se traza con un zoom de 10x).  Para hacer esto, Folium nos da tres parámetros: ``zoom_start``, ``min_zoom`` y ``max_zoom``.
#
# Entonces, tracemos nuevamente el mapa de Mérida pero esta vez de con un nivel de zoom desde el inicio:

# %%
mapa = folium.Map(location=[20.9785, -89.6332],zoom_start=12)
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ea285bd66d28747bdb0c06f331b206de {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ea285bd66d28747bdb0c06f331b206de&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ea285bd66d28747bdb0c06f331b206de = L.map(
#                 &quot;map_ea285bd66d28747bdb0c06f331b206de&quot;,
#                 {
#                     center: [20.9785, -89.6332],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e596ce6676661779360967e16c5407f6 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ea285bd66d28747bdb0c06f331b206de);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Ahora tracemos nuevamente el mapa de Mérida  con un nivel de zoom restringido:

# %%
mapa = folium.Map(location=[20.9785, -89.6332],zoom_start=12,min_zoom=10,max_zoom=13)
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_942cf716ab9d3ba673d7b13b4a309d89 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_942cf716ab9d3ba673d7b13b4a309d89&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_942cf716ab9d3ba673d7b13b4a309d89 = L.map(
#                 &quot;map_942cf716ab9d3ba673d7b13b4a309d89&quot;,
#                 {
#                     center: [20.9785, -89.6332],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7908117d9918992b607e4b43979392fc = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 13, &quot;maxZoom&quot;: 13, &quot;minZoom&quot;: 10, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_942cf716ab9d3ba673d7b13b4a309d89);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Marcadores en el mapa

# %% [markdown]
# Los marcadores son los elementos que se utilizan para marcar una ubicación en un mapa. Por ejemplo, cuando utiliza _Google Maps_ para la navegación, su ubicación se marca con un marcador y su destino se marca con otro marcador. Los marcadores se encuentran entre los elementos más importantes y útiles de un mapa.
#
# _**Folium**_ proporciona una clase  ``folium.Marker ()``  para trazar marcadores en un mapa. Simplemente pase la latitud y la longitud de la ubicación, mencione la ventana emergente y la información sobre herramientas y agréguela al mapa.
#
# Agregar marcadores es un proceso de dos pasos. Primero, debe crear un mapa base en el que se colocarán sus marcadores, y luego agregar sus marcadores. En el siguiente ejemplo se muestra su implementación junto con algunas opciones extras de visualización:

# %%
# Mapa de base
mapa=folium.Map(location=[20.9785, -89.6332],zoom_start=12)
# Agregar marcadores al mapa
folium.Marker(location=[21.04829, -89.64025],popup='FIUADY').add_to(mapa)
folium.Marker(location=[20.96972, -89.62272],popup='<strong>Edificio Central UADY</strong>',tooltip='<strong>Click here to see Popup</strong>').add_to(mapa)
folium.Marker(location=[20.94167,-89.59466],popup='<h3 style="color:green;">Estadio Kukulc&aacute;n</h3>',tooltip='<strong>Click here to see Popup</strong>').add_to(mapa)

mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_64ea1d740bd33daa721961bb3819e152 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_64ea1d740bd33daa721961bb3819e152&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_64ea1d740bd33daa721961bb3819e152 = L.map(
#                 &quot;map_64ea1d740bd33daa721961bb3819e152&quot;,
#                 {
#                     center: [20.9785, -89.6332],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0997b7b08fa9dd42fb11ccf49a9706d7 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_64ea1d740bd33daa721961bb3819e152);
#
#
#             var marker_8c7fc9fe2b47e9380f64d8a31916d958 = L.marker(
#                 [21.04829, -89.64025],
#                 {}
#             ).addTo(map_64ea1d740bd33daa721961bb3819e152);
#
#
#         var popup_dc00b66c5f83496268760335c8a48a45 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d9a2afdddfd9146a221ae8014fe69d81 = $(`&lt;div id=&quot;html_d9a2afdddfd9146a221ae8014fe69d81&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;FIUADY&lt;/div&gt;`)[0];
#                 popup_dc00b66c5f83496268760335c8a48a45.setContent(html_d9a2afdddfd9146a221ae8014fe69d81);
#
#
#
#         marker_8c7fc9fe2b47e9380f64d8a31916d958.bindPopup(popup_dc00b66c5f83496268760335c8a48a45)
#         ;
#
#
#
#
#             var marker_bdaedc411ec5b9cf060fe31d3707fa36 = L.marker(
#                 [20.96972, -89.62272],
#                 {}
#             ).addTo(map_64ea1d740bd33daa721961bb3819e152);
#
#
#         var popup_d1f2101bd39b41e5eac7bfc6a6001b76 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f16a8d857c55ccd3557e9467eee92121 = $(`&lt;div id=&quot;html_f16a8d857c55ccd3557e9467eee92121&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;Edificio Central UADY&lt;/strong&gt;&lt;/div&gt;`)[0];
#                 popup_d1f2101bd39b41e5eac7bfc6a6001b76.setContent(html_f16a8d857c55ccd3557e9467eee92121);
#
#
#
#         marker_bdaedc411ec5b9cf060fe31d3707fa36.bindPopup(popup_d1f2101bd39b41e5eac7bfc6a6001b76)
#         ;
#
#
#
#
#             marker_bdaedc411ec5b9cf060fe31d3707fa36.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;strong&gt;Click here to see Popup&lt;/strong&gt;
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_d51e80b10eb855b88d4c47204045c203 = L.marker(
#                 [20.94167, -89.59466],
#                 {}
#             ).addTo(map_64ea1d740bd33daa721961bb3819e152);
#
#
#         var popup_bdabd720a867ad9ab3f8ff7477ebeb6f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_00ce8a1f7dc0cbd81e279381508f4f87 = $(`&lt;div id=&quot;html_00ce8a1f7dc0cbd81e279381508f4f87&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;h3 style=&quot;color:green;&quot;&gt;Estadio Kukulc&amp;aacute;n&lt;/h3&gt;&lt;/div&gt;`)[0];
#                 popup_bdabd720a867ad9ab3f8ff7477ebeb6f.setContent(html_00ce8a1f7dc0cbd81e279381508f4f87);
#
#
#
#         marker_d51e80b10eb855b88d4c47204045c203.bindPopup(popup_bdabd720a867ad9ab3f8ff7477ebeb6f)
#         ;
#
#
#
#
#             marker_d51e80b10eb855b88d4c47204045c203.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;strong&gt;Click here to see Popup&lt;/strong&gt;
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# En el mapa anteriorcuando pasa el cursor sobre un marcador el texto que aparece se conoce como ``tooltip`` (información sobre herramienta)  y el texto cuando hace clic en un marcador se conoce como una ``popup`` (ventana emergente). Si se observa detenidamente, se ha  personalizado la información  de los marcadores 2 y 3.

# %% [markdown]
# ## Marcadores personalizados

# %% [markdown]
# Para mejorar la visualización puede cambiar el icono del marcador, Folium proporciona la clase ``folium.Icon()`` que se puede utilizar para crear iconos personalizados para marcadores. Puede elegir iconos entre una amplia gama de opciones.
#
# ``Icon()`` toma tres argumentos: color, prefijo e icono. El color se utiliza para cambiar el color del marcador, el prefijo se utiliza para seleccionar el proveedor de iconos (prefix='fa' para https://fontawesome.com/icons?d=gallery&m=free y  prefix='glyphicon' para  https://getbootstrap.com/docs/3.3/components/) y el icono se utiliza para seleccionar el nombre del icono.

# %%
# Mapa de base
mapa=folium.Map(location=[20.9785, -89.6332],zoom_start=12)
# Agregar marcadores al mapa
folium.Marker(location=[21.04829, -89.64025], popup='FIUADY',  
             icon=folium.Icon(color='red', prefix='fa', icon='school') ).add_to(mapa)

folium.Marker(location=[20.96972, -89.62272],popup='<strong>Edificio Central UADY</strong>',
              tooltip='<strong>Click here to see Popup</strong>',
              icon=folium.Icon(color='green',prefix='fa',icon='crosshairs')     ).add_to(mapa)


folium.Marker(location=[20.94167,-89.59466],popup='<h3 style="color:green;">Estadio Kukulc&aacute;n</h3>',
              tooltip='<strong>Click here to see Popup</strong>',
              icon=folium.Icon(color='purple',prefix='glyphicon',icon='camera')   ).add_to(mapa)

mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d327358910c98254552423afe699ffb2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d327358910c98254552423afe699ffb2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d327358910c98254552423afe699ffb2 = L.map(
#                 &quot;map_d327358910c98254552423afe699ffb2&quot;,
#                 {
#                     center: [20.9785, -89.6332],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_656ebd53aeaa36339ee207b8c009d9e2 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d327358910c98254552423afe699ffb2);
#
#
#             var marker_be12fabf744b2ce33b5504e3553c7d96 = L.marker(
#                 [21.04829, -89.64025],
#                 {}
#             ).addTo(map_d327358910c98254552423afe699ffb2);
#
#
#             var icon_011e82cfdd00149f7272aa1222457454 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;school&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_be12fabf744b2ce33b5504e3553c7d96.setIcon(icon_011e82cfdd00149f7272aa1222457454);
#
#
#         var popup_0b31b5b19221037bcbebc5fa1a42c818 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d32d77db0395ad359afef6ab607d45ff = $(`&lt;div id=&quot;html_d32d77db0395ad359afef6ab607d45ff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;FIUADY&lt;/div&gt;`)[0];
#                 popup_0b31b5b19221037bcbebc5fa1a42c818.setContent(html_d32d77db0395ad359afef6ab607d45ff);
#
#
#
#         marker_be12fabf744b2ce33b5504e3553c7d96.bindPopup(popup_0b31b5b19221037bcbebc5fa1a42c818)
#         ;
#
#
#
#
#             var marker_a52809124fe6acbb018164dc212cdefd = L.marker(
#                 [20.96972, -89.62272],
#                 {}
#             ).addTo(map_d327358910c98254552423afe699ffb2);
#
#
#             var icon_c4dfbd3ff18915dec85bf7f9a2c596db = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;crosshairs&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_a52809124fe6acbb018164dc212cdefd.setIcon(icon_c4dfbd3ff18915dec85bf7f9a2c596db);
#
#
#         var popup_f7dfa0266593459ad91b895bb8ecb605 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7fdcc6a359c4b5a053301c03c30ee070 = $(`&lt;div id=&quot;html_7fdcc6a359c4b5a053301c03c30ee070&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;Edificio Central UADY&lt;/strong&gt;&lt;/div&gt;`)[0];
#                 popup_f7dfa0266593459ad91b895bb8ecb605.setContent(html_7fdcc6a359c4b5a053301c03c30ee070);
#
#
#
#         marker_a52809124fe6acbb018164dc212cdefd.bindPopup(popup_f7dfa0266593459ad91b895bb8ecb605)
#         ;
#
#
#
#
#             marker_a52809124fe6acbb018164dc212cdefd.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;strong&gt;Click here to see Popup&lt;/strong&gt;
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_812eb189b8edfeb907cb245d13869465 = L.marker(
#                 [20.94167, -89.59466],
#                 {}
#             ).addTo(map_d327358910c98254552423afe699ffb2);
#
#
#             var icon_e422bfc76afe1ebccbdc18a49b19eb35 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;camera&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;purple&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_812eb189b8edfeb907cb245d13869465.setIcon(icon_e422bfc76afe1ebccbdc18a49b19eb35);
#
#
#         var popup_082f85d3d3950af3857a2d12d11e965b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2bca1a69b9f4a9cf6c6e3b91781f7b62 = $(`&lt;div id=&quot;html_2bca1a69b9f4a9cf6c6e3b91781f7b62&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;h3 style=&quot;color:green;&quot;&gt;Estadio Kukulc&amp;aacute;n&lt;/h3&gt;&lt;/div&gt;`)[0];
#                 popup_082f85d3d3950af3857a2d12d11e965b.setContent(html_2bca1a69b9f4a9cf6c6e3b91781f7b62);
#
#
#
#         marker_812eb189b8edfeb907cb245d13869465.bindPopup(popup_082f85d3d3950af3857a2d12d11e965b)
#         ;
#
#
#
#
#             marker_812eb189b

# %% [markdown]
# ## Marcadores  tipo circunferencia

# %% [markdown]
# Se realiza mediante la función ``folium.Circle``. Cada circunferencia tiene un tamaño relacionado con un valor específico, a través del parametro ``radius`` (metros).

# %%
mapa=folium.Map(location=[20.9785, -89.6332],zoom_start=12 )
# Agregar marcadores al mapa
folium.Marker(location=[21.04829, -89.64025], popup='FIUADY',  
             icon=folium.Icon(color='red',icon='none') ).add_to(mapa)

folium.Marker(location=[20.96972, -89.62272],popup='<strong>Edificio Central UADY</strong>',
              tooltip='<strong>Click here to see Popup</strong>',
              icon=folium.Icon(color='green',prefix='fa',icon='crosshairs')     ).add_to(mapa)


folium.Marker(location=[20.94167,-89.59466],popup='<h3 style="color:green;">Estadio Kukulc&aacute;n</h3>',
              tooltip='<strong>Click here to see Popup</strong>',
              icon=folium.Icon(color='purple',prefix='glyphicon',icon='camera')   ).add_to(mapa)


folium.Circle(
    radius=500,
    location=[20.956972, -89.62272],
    popup='Sur',
    color='crimson',
    fill=False,
).add_to(mapa)

folium.Circle(
    location=[20.996972, -89.62272],
    radius=1500,
    popup='Norte',
    color='#3186cc',
    fill=True,
    fill_color='#3186cc'
).add_to(mapa)


mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_630688df69f2ffe8750d99780f99cf29 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_630688df69f2ffe8750d99780f99cf29&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_630688df69f2ffe8750d99780f99cf29 = L.map(
#                 &quot;map_630688df69f2ffe8750d99780f99cf29&quot;,
#                 {
#                     center: [20.9785, -89.6332],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3f9fe0f77679839fb72be6336717a186 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_630688df69f2ffe8750d99780f99cf29);
#
#
#             var marker_29b0d550edcf8db8a449c3dd708dc79d = L.marker(
#                 [21.04829, -89.64025],
#                 {}
#             ).addTo(map_630688df69f2ffe8750d99780f99cf29);
#
#
#             var icon_643d7f6ff044c0a46b634c85eced22a0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;none&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_29b0d550edcf8db8a449c3dd708dc79d.setIcon(icon_643d7f6ff044c0a46b634c85eced22a0);
#
#
#         var popup_9268eb8ce2617c7a6ec8b0ca08af37f5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f2dbcfcdeb4192fa7776f7be0933030b = $(`&lt;div id=&quot;html_f2dbcfcdeb4192fa7776f7be0933030b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;FIUADY&lt;/div&gt;`)[0];
#                 popup_9268eb8ce2617c7a6ec8b0ca08af37f5.setContent(html_f2dbcfcdeb4192fa7776f7be0933030b);
#
#
#
#         marker_29b0d550edcf8db8a449c3dd708dc79d.bindPopup(popup_9268eb8ce2617c7a6ec8b0ca08af37f5)
#         ;
#
#
#
#
#             var marker_7726c57341c9d50f38f78e89200b6ee8 = L.marker(
#                 [20.96972, -89.62272],
#                 {}
#             ).addTo(map_630688df69f2ffe8750d99780f99cf29);
#
#
#             var icon_808113c98312838f28c7ea7119e9609f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;crosshairs&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_7726c57341c9d50f38f78e89200b6ee8.setIcon(icon_808113c98312838f28c7ea7119e9609f);
#
#
#         var popup_964eb064c0765c1c323492a04af132a2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_adc8aea9638804f03ae68223e45b3960 = $(`&lt;div id=&quot;html_adc8aea9638804f03ae68223e45b3960&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;Edificio Central UADY&lt;/strong&gt;&lt;/div&gt;`)[0];
#                 popup_964eb064c0765c1c323492a04af132a2.setContent(html_adc8aea9638804f03ae68223e45b3960);
#
#
#
#         marker_7726c57341c9d50f38f78e89200b6ee8.bindPopup(popup_964eb064c0765c1c323492a04af132a2)
#         ;
#
#
#
#
#             marker_7726c57341c9d50f38f78e89200b6ee8.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;strong&gt;Click here to see Popup&lt;/strong&gt;
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_b111c520c3d254c58ad31436031c5897 = L.marker(
#                 [20.94167, -89.59466],
#                 {}
#             ).addTo(map_630688df69f2ffe8750d99780f99cf29);
#
#
#             var icon_ce29547b6bff43384d10f8f2af7c5ce4 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;camera&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;purple&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_b111c520c3d254c58ad31436031c5897.setIcon(icon_ce29547b6bff43384d10f8f2af7c5ce4);
#
#
#         var popup_65e2c2e6f933e894868b84d2acf1b9ba = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d0efc89dd081c58bc871b0af7c092c36 = $(`&lt;div id=&quot;html_d0efc89dd081c58bc871b0af7c092c36&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;h3 style=&quot;color:green;&quot;&gt;Estadio Kukulc&amp;aacute;n&lt;/h3&gt;&lt;/div&gt;`)[0];
#                 popup_65e2c2e6f933e894868b84d2acf1b9ba.setContent(html_d0efc89dd081c58bc871b0af7c092c36);
#
#
#
#         marker_b111c520c3d254c58ad31436031c5897.bindPopup(popup_65e2c2e6f933e894868b84d2acf1b9ba)
#         ;
#
#
#
#
#             marker_b111

# %% [markdown]
# # Estilo del mapa

# %% [markdown]
# El estilo predeterminado se encuentra con la opción ``OpenStreetMap``, pero tambien cuenta con ``Stamen Terrain``, ``Stamen Toner``, ``Mapbox Bright``,  ``Mapbox Control Room`` y otros (https://deparkes.co.uk/2016/06/10/folium-map-tiles/).

# %% [markdown]
# ###  Stamen Toner

# %%
# Mapa de base
# Mapa de base
mapa=folium.Map(location=[20.9785, -89.6332],zoom_start=12,  tiles ='Stamen Toner')
# Agregar marcadores al mapa
folium.Marker(location=[21.04829, -89.64025], popup='FIUADY',  
             icon=folium.Icon(color='red',icon='none') ).add_to(mapa)

folium.Marker(location=[20.96972, -89.62272],popup='<strong>Edificio Central UADY</strong>',
              tooltip='<strong>Click here to see Popup</strong>',
              icon=folium.Icon(color='green',prefix='fa',icon='crosshairs')     ).add_to(mapa)


folium.Marker(location=[20.94167,-89.59466],popup='<h3 style="color:green;">Estadio Kukulc&aacute;n</h3>',
              tooltip='<strong>Click here to see Popup</strong>',
              icon=folium.Icon(color='purple',prefix='glyphicon',icon='camera')   ).add_to(mapa)

folium.Circle(
    radius=500,
    location=[20.956972, -89.62272],
    popup='Sur',
    color='crimson',
    fill=False,
).add_to(mapa)

folium.Circle(
    location=[20.996972, -89.62272],
    radius=1500,
    popup='Norte',
    color='#3186cc',
    fill=True,
    fill_color='#3186cc'
).add_to(mapa)

mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d8d0815c1f5b1b10b777a97a39ab63a5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d8d0815c1f5b1b10b777a97a39ab63a5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d8d0815c1f5b1b10b777a97a39ab63a5 = L.map(
#                 &quot;map_d8d0815c1f5b1b10b777a97a39ab63a5&quot;,
#                 {
#                     center: [20.9785, -89.6332],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9ebc7f691b0b3c3b168b1ea05d65769e = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d8d0815c1f5b1b10b777a97a39ab63a5);
#
#
#             var marker_28da9ed91730da1a91416b9f2e26957a = L.marker(
#                 [21.04829, -89.64025],
#                 {}
#             ).addTo(map_d8d0815c1f5b1b10b777a97a39ab63a5);
#
#
#             var icon_71c0586f0b17505dd83be065689f505d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;none&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_28da9ed91730da1a91416b9f2e26957a.setIcon(icon_71c0586f0b17505dd83be065689f505d);
#
#
#         var popup_01f95ea3ca56ed478e9b36ead2a0decc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8775c512b16bd59fb339628dc1a3bd64 = $(`&lt;div id=&quot;html_8775c512b16bd59fb339628dc1a3bd64&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;FIUADY&lt;/div&gt;`)[0];
#                 popup_01f95ea3ca56ed478e9b36ead2a0decc.setContent(html_8775c512b16bd59fb339628dc1a3bd64);
#
#
#
#         marker_28da9ed91730da1a91416b9f2e26957a.bindPopup(popup_01f95ea3ca56ed478e9b36ead2a0decc)
#         ;
#
#
#
#
#             var marker_457070ee595980d5f41718c445053121 = L.marker(
#                 [20.96972, -89.62272],
#                 {}
#             ).addTo(map_d8d0815c1f5b1b10b777a97a39ab63a5);
#
#
#             var icon_4b9675f0c7bdb9b6dcd51fc90a43730c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;crosshairs&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_457070ee595980d5f41718c445053121.setIcon(icon_4b9675f0c7bdb9b6dcd51fc90a43730c);
#
#
#         var popup_aebea3b15526912f6604438f2ee807f7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a095105550512c830a77c344fd8cc0be = $(`&lt;div id=&quot;html_a095105550512c830a77c344fd8cc0be&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;Edificio Central UADY&lt;/strong&gt;&lt;/div&gt;`)[0];
#                 popup_aebea3b15526912f6604438f2ee807f7.setContent(html_a095105550512c830a77c344fd8cc0be);
#
#
#
#         marker_457070ee595980d5f41718c445053121.bindPopup(popup_aebea3b15526912f6604438f2ee807f7)
#         ;
#
#
#
#
#             marker_457070ee595980d5f41718c445053121.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;strong&gt;Click here to see Popup&lt;/strong&gt;
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_5ebcd524caee161816443bd8c3e0b67d = L.marker(
#                 [20.94167, -89.59466],
#                 {}
#             ).addTo(map_d8d0815c1f5b1b10b777a97a39ab63a5);
#
#
#             var icon_ce9833d88a4973839afee793fc02151a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;camera&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;purple&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_5ebcd524caee161816443bd8c3e0b67d.setIcon(icon_ce9833d88a4973839afee793fc02151a);
#
#
#         var popup_465be9b579a9b67b81bd0a5d2d7f96f4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5f0ca90cbc0cc84f2b2cfb2782619242 = $(`&lt;div id=&quot;html_5f0ca90cbc0cc84f2b2cfb2782619242&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;h3 style=&quot;color:green;&quot;&gt;Estadio Kukulc&amp;aacute;n&lt;/h3&gt;&lt;/div&gt;`)[0];

# %% [markdown]
# ### Mapbox Bright

# %%
# Mapa de base
# Mapa de base
mapa=folium.Map(location=[20.9785, -89.6332],zoom_start=12,  tiles ='Stamen Terrain')
# Agregar marcadores al mapa
folium.Marker(location=[21.04829, -89.64025], popup='FIUADY',  
             icon=folium.Icon(color='red',icon='none') ).add_to(mapa)

folium.Marker(location=[20.96972, -89.62272],popup='<strong>Edificio Central UADY</strong>',
              tooltip='<strong>Click here to see Popup</strong>',
              icon=folium.Icon(color='green',prefix='fa',icon='crosshairs')     ).add_to(mapa)


folium.Marker(location=[20.94167,-89.59466],popup='<h3 style="color:green;">Estadio Kukulc&aacute;n</h3>',
              tooltip='<strong>Click here to see Popup</strong>',
              icon=folium.Icon(color='purple',prefix='glyphicon',icon='camera')   ).add_to(mapa)

folium.Circle(
    radius=500,
    location=[20.956972, -89.62272],
    popup='Sur',
    color='crimson',
    fill=False,
).add_to(mapa)

folium.Circle(
    location=[20.996972, -89.62272],
    radius=1500,
    popup='Norte',
    color='#3186cc',
    fill=True,
    fill_color='#3186cc'
).add_to(mapa)

mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6558d62a2031a57a3e7ff73d10183509 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6558d62a2031a57a3e7ff73d10183509&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6558d62a2031a57a3e7ff73d10183509 = L.map(
#                 &quot;map_6558d62a2031a57a3e7ff73d10183509&quot;,
#                 {
#                     center: [20.9785, -89.6332],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e7110af4026e3c881aa2c2c1ca57b27d = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6558d62a2031a57a3e7ff73d10183509);
#
#
#             var marker_0c03d104351c27d897e80e4863e41e4f = L.marker(
#                 [21.04829, -89.64025],
#                 {}
#             ).addTo(map_6558d62a2031a57a3e7ff73d10183509);
#
#
#             var icon_36cd6d90f04ccaab3cef7fd15e353a04 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;none&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_0c03d104351c27d897e80e4863e41e4f.setIcon(icon_36cd6d90f04ccaab3cef7fd15e353a04);
#
#
#         var popup_86cbc9c355ec12d15786a696f00c8f12 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cdfe843f58310dab6696c25f23e2caf7 = $(`&lt;div id=&quot;html_cdfe843f58310dab6696c25f23e2caf7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;FIUADY&lt;/div&gt;`)[0];
#                 popup_86cbc9c355ec12d15786a696f00c8f12.setContent(html_cdfe843f58310dab6696c25f23e2caf7);
#
#
#
#         marker_0c03d104351c27d897e80e4863e41e4f.bindPopup(popup_86cbc9c355ec12d15786a696f00c8f12)
#         ;
#
#
#
#
#             var marker_2520ef0398370296b145d2f3f2cd17a1 = L.marker(
#                 [20.96972, -89.62272],
#                 {}
#             ).addTo(map_6558d62a2031a57a3e7ff73d10183509);
#
#
#             var icon_18928208dc8333340aa7d74d077456f5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;crosshairs&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_2520ef0398370296b145d2f3f2cd17a1.setIcon(icon_18928208dc8333340aa7d74d077456f5);
#
#
#         var popup_418a972f074072367b288441036a0aec = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3ff2972e8c3a039f831439ba5050fa84 = $(`&lt;div id=&quot;html_3ff2972e8c3a039f831439ba5050fa84&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;Edificio Central UADY&lt;/strong&gt;&lt;/div&gt;`)[0];
#                 popup_418a972f074072367b288441036a0aec.setContent(html_3ff2972e8c3a039f831439ba5050fa84);
#
#
#
#         marker_2520ef0398370296b145d2f3f2cd17a1.bindPopup(popup_418a972f074072367b288441036a0aec)
#         ;
#
#
#
#
#             marker_2520ef0398370296b145d2f3f2cd17a1.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;strong&gt;Click here to see Popup&lt;/strong&gt;
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_5ab62407837e5e28a5c98ad8d5189266 = L.marker(
#                 [20.94167, -89.59466],
#                 {}
#             ).addTo(map_6558d62a2031a57a3e7ff73d10183509);
#
#
#             var icon_5f5c64d55f7761f0ecf32eb793436eee = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;camera&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;purple&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_5ab62407837e5e28a5c98ad8d5189266.setIcon(icon_5f5c64d55f7761f0ecf32eb793436eee);
#
#
#         var popup_0181a1b04ec8d37c2ecb779041ef753e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b47e306bb14a424c0a7a94d556a372a9 = $(`&lt;div id=&quot;html_b47e306bb14a424c0a7a94d556a372a9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;h3 style=&quot;color:green;&quot;&gt;Estadio Kukulc&amp;aacute;n&lt;/h3&gt;&lt;/div&gt;`)[0];
