# %% [markdown]
# # Población total en México a lo largo del tiempo

# %% [markdown]
# ## 1. Cargar los datos

# %%
# Cargar las biblioteca Pandas con el alias 'pd’
# Cargar las biblioteca Matplotlib con el alias ‘plt’
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# En este notebook se utilizará la gráfica de la población total en México a lo largo de los años
# *Fuente:* https://datos.bancomundial.org/indicator/SP.POP.TOTL?end=2022&start=1960&view=chart
# ![Imagen: población en México (obtenida del idle)](figuras/población_méxico.png)

# %% [markdown]
# En este notebook se utilizará la gráfica de la cronología de los precios de los teléfonos móviles a lo largo de los años
# *Fuente:* https://datos.bancomundial.org/indicator/SP.POP.TOTL?end=2022&start=1960&view=chart
#
# <img src="figuras/población_méxico.png" width=250/>

# %%
# Leer datos del archivo datos.csv
data = pd.read_csv("datos/población_méxico.csv")

# %%
# Vista previa de las primeras 5 líneas de los datos cargados
data.head()
# Out:
#     Año   Población
# 0  1960  36268055.0
# 1  1961  37439317.0
# 2  1962  38683283.0
# 3  1963  39982118.0
# 4  1964  41333878.0

# %% [markdown]
# ## 2. Graficar los datos

# %%
#Graficamos las variables
data.plot(x='Año', y='Población', kind='line')
plt.show('figuras/población_méxico.png')
