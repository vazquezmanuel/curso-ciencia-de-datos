# %% [markdown]
# <br><br><center><h1 style="font-size:2em;color:#2467C0">Caso de estudio: Delitos en Estados Unidos </h1></center>
# <br>
# <table>
# <col width="550">
# <col width="450">
# <tr>

# %% [markdown]
# # 1. Importar librerías generales

# %%
import numpy as np  
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sn

# %matplotlib inline

# %% [markdown]
# # 2. Obtención de datos

# %%
df = pd.read_csv('datos/indice_paz_mex_impacto-economico_2020.csv', encoding = 'ISO-8859-1')

# %%
df.head()
# Out:
#                Estados  Homicidio  Delitos_con_violencia  \
# 0       AGUASCALIENTES      1.368                  3.167
# 1      BAJA_CALIFORNIA      5.000                  3.296
# 2  BAJA_CALIFORNIA_SUR      1.554                  3.411
# 3             CAMPECHE      1.533                  1.223
# 4              CHIAPAS      1.544                  1.444
#
#    Delitos_con_armas_fuego  Delincuencia_organizada  Carcel_Sin_sentencia  \
# 0                    1.490                    3.425                 1.307
# 1                    5.000                    5.000                 2.110
# 2                    1.274                    5.000                 1.496
# 3                    1.345                    1.723                 4.297
# 4                    1.372                    1.629                 2.874
#
#    Impacto_economico_de_la_violencia  \
# 0                               51.9
# 1                              259.6
# 2                               28.8
# 3                               21.6
# 4                               78.7
#
#   Impacto_economico_per_capita_de_la_violencia  porcen_pib
# 0                                       36,158        14.5
# 1                                       71,413        31.5
# 2                                       35,761        13.4
# 3                                       21,543         2.2
# 4                                       13,742        17.8

# %%
df.dtypes
# Out:
# Estados                                          object
# Homicidio                                       float64
# Delitos_con_violencia                           float64
# Delitos_con_armas_fuego                         float64
# Delincuencia_organizada                         float64
# Carcel_Sin_sentencia                            float64
# Impacto_economico_de_la_violencia               float64
# Impacto_economico_per_capita_de_la_violencia     object
# porcen_pib                                      float64
# dtype: object

# %%
df.head()
# Out:
#                Estados  Homicidio  Delitos_con_violencia  \
# 0       AGUASCALIENTES      1.368                  3.167
# 1      BAJA_CALIFORNIA      5.000                  3.296
# 2  BAJA_CALIFORNIA_SUR      1.554                  3.411
# 3             CAMPECHE      1.533                  1.223
# 4              CHIAPAS      1.544                  1.444
#
#    Delitos_con_armas_fuego  Delincuencia_organizada  Carcel_Sin_sentencia  \
# 0                    1.490                    3.425                 1.307
# 1                    5.000                    5.000                 2.110
# 2                    1.274                    5.000                 1.496
# 3                    1.345                    1.723                 4.297
# 4                    1.372                    1.629                 2.874
#
#    Impacto_economico_de_la_violencia  \
# 0                               51.9
# 1                              259.6
# 2                               28.8
# 3                               21.6
# 4                               78.7
#
#   Impacto_economico_per_capita_de_la_violencia  porcen_pib
# 0                                       36,158        14.5
# 1                                       71,413        31.5
# 2                                       35,761        13.4
# 3                                       21,543         2.2
# 4                                       13,742        17.8

# %%
df.columns
# Out:
# Index(['Estados', 'Homicidio', 'Delitos_con_violencia',
#        'Delitos_con_armas_fuego', 'Delincuencia_organizada',
#        'Carcel_Sin_sentencia', 'Impacto_economico_de_la_violencia',
#        'Impacto_economico_per_capita_de_la_violencia', 'porcen_pib'],
#       dtype='object')

# %%
# Para agregar el id
df['Estados'] = df['Estados'].str.replace('_', ' ')
df = df.set_index('Estados')
df.head()
# Out:
#                      Homicidio  Delitos_con_violencia  \
# Estados
# AGUASCALIENTES           1.368                  3.167
# BAJA CALIFORNIA          5.000                  3.296
# BAJA CALIFORNIA SUR      1.554                  3.411
# CAMPECHE                 1.533                  1.223
# CHIAPAS                  1.544                  1.444
#
#                      Delitos_con_armas_fuego  Delincuencia_organizada  \
# Estados
# AGUASCALIENTES                         1.490                    3.425
# BAJA CALIFORNIA                        5.000                    5.000
# BAJA CALIFORNIA SUR                    1.274                    5.000
# CAMPECHE                               1.345                    1.723
# CHIAPAS                                1.372                    1.629
#
#                      Carcel_Sin_sentencia  Impacto_economico_de_la_violencia  \
# Estados
# AGUASCALIENTES                      1.307                               51.9
# BAJA CALIFORNIA                     2.110                              259.6
# BAJA CALIFORNIA SUR                 1.496                               28.8
# CAMPECHE                            4.297                               21.6
# CHIAPAS                             2.874                               78.7
#
#                     Impacto_economico_per_capita_de_la_violencia  porcen_pib
# Estados
# AGUASCALIENTES                                            36,158        14.5
# BAJA CALIFORNIA                                           71,413        31.5
# BAJA CALIFORNIA SUR                                       35,761        13.4
# CAMPECHE                                                  21,543         2.2
# CHIAPAS                                                   13,742        17.8

# %%
# Leyendo id
df_id = pd.read_csv('datos/estados_id.csv')
df_id.head()
# Out:
#                ENTIDAD IDNAME
# 0       Aguascalientes     AS
# 1      Baja California     BC
# 2  Baja California Sur     BS
# 3             Campeche     CC
# 4                 CDMX     DF

# %%
# Haciendo que coincidan los nombres
df_id['ENTIDAD'] = df_id['ENTIDAD'].str.upper()
df_id['ENTIDAD'].iloc[4] = 'CIUDAD DE MÉXICO'
df_id.columns = ['Estados', 'id']
df_id = df_id.set_index('Estados')
df_id.head()
# Out:
#                      id
# Estados
# AGUASCALIENTES       AS
# BAJA CALIFORNIA      BC
# BAJA CALIFORNIA SUR  BS
# CAMPECHE             CC
# CIUDAD DE MÉXICO     DF

# %%
# Juntando los dataframes
df = df.join(df_id)
df.head()
# Out:
#                      Homicidio  Delitos_con_violencia  \
# Estados
# AGUASCALIENTES           1.368                  3.167
# BAJA CALIFORNIA          5.000                  3.296
# BAJA CALIFORNIA SUR      1.554                  3.411
# CAMPECHE                 1.533                  1.223
# CHIAPAS                  1.544                  1.444
#
#                      Delitos_con_armas_fuego  Delincuencia_organizada  \
# Estados
# AGUASCALIENTES                         1.490                    3.425
# BAJA CALIFORNIA                        5.000                    5.000
# BAJA CALIFORNIA SUR                    1.274                    5.000
# CAMPECHE                               1.345                    1.723
# CHIAPAS                                1.372                    1.629
#
#                      Carcel_Sin_sentencia  Impacto_economico_de_la_violencia  \
# Estados
# AGUASCALIENTES                      1.307                               51.9
# BAJA CALIFORNIA                     2.110                              259.6
# BAJA CALIFORNIA SUR                 1.496                               28.8
# CAMPECHE                            4.297                               21.6
# CHIAPAS                             2.874                               78.7
#
#                     Impacto_economico_per_capita_de_la_violencia  porcen_pib  \
# Estados
# AGUASCALIENTES                                            36,158        14.5
# BAJA CALIFORNIA                                           71,413        31.5
# BAJA CALIFORNIA SUR                                       35,761        13.4
# CAMPECHE                                                  21,543         2.2
# CHIAPAS                                                   13,742        17.8
#
#                      id
# Estados
# AGUASCALIENTES       AS
# BAJA CALIFORNIA      BC
# BAJA CALIFORNIA SUR  BS
# CAMPECHE             CC
# CHIAPAS              CS

# %% [markdown]
# # 3. Análisis Exploratorio

# %%
#Principales parámetros estadísticos
df.describe().transpose()
# Out:
#                                    count        mean         std     min  \
# Homicidio                           32.0    2.720625    1.287674   1.167
# Delitos_con_violencia               32.0    2.705656    0.847171   1.133
# Delitos_con_armas_fuego             32.0    2.575781    1.260074   1.042
# Delincuencia_organizada             32.0    2.883594    1.102784   1.454
# Carcel_Sin_sentencia                32.0    1.895000    0.862432   1.271
# Impacto_economico_de_la_violencia   32.0  147.328125  132.126921  21.600
# porcen_pib                          32.0   20.946875   12.109766   2.200
#
#                                         25%       50%        75%      max
# Homicidio                           1.63275    2.1860    3.59925    5.000
# Delitos_con_violencia               2.27850    2.7295    3.30025    4.783
# Delitos_con_armas_fuego             1.49675    2.3575    3.15475    5.000
# Delincuencia_organizada             1.82275    2.7020    3.57425    5.000
# Carcel_Sin_sentencia                1.41700    1.5270    1.89400    5.000
# Impacto_economico_de_la_violencia  60.65000  100.3000  199.22500  589.700
# porcen_pib                         13.77500   17.1500   29.62500   44.100

# %%
# Correlación lineal de variables
sn.pairplot(df, kind="reg",  height=1.7 , aspect=1)
# Out:
# /home/manuel/.pyenv/versions/3.11.4/envs/DS/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# # 4. Correlación de variables

# %%
# Las variables a analizar serán:
atributos = ['Homicidio', 'Delitos_con_violencia', 'Delincuencia_organizada', 'Delitos_con_armas_fuego']

# %%
plt.figure(figsize=(6,6))
sn.heatmap(df[atributos].corr(), annot=True)
# Out:
# <Axes: >

# %% [markdown]
# Se observa una correlación lineal entre el número de homicidios y los delitos con armas de fuego. En el análisis se incluirán las dos variables.

# %% [markdown]
# # 5. Normalización de datos

# %%
#Re-esalamiento de variables
from sklearn import preprocessing
df_standardized = preprocessing.scale(df[atributos])

# %%
#Comparación antes y despues de la normalización (re-escalamiento)
Murder_list=df_standardized[:,:1].flatten()
fig, (ax1, ax2) = plt.subplots(2)
fig.suptitle('Homocidio')
ax1.hist(df['Homicidio'])
ax2.hist( Murder_list)
# Out:
# (array([5., 7., 5., 4., 1., 1., 1., 2., 1., 5.]),
#  array([-1.225842  , -0.92341043, -0.62097887, -0.31854731, -0.01611574,
#          0.28631582,  0.58874738,  0.89117894,  1.19361051,  1.49604207,
#          1.79847363]),
#  <BarContainer object of 10 artists>)

# %%
# Data frame que servirá para la predicción de grupos
df_standardized = pd.DataFrame(df_standardized)

# %%
df_standardized.head()
# Out:
#           0         1         2         3
# 0 -1.067249  0.553284  0.498801 -0.875468
# 1  1.798474  0.707992  1.949857  1.954654
# 2 -0.920491  0.845910  1.949857 -1.049630
# 3 -0.937060 -1.778131 -1.069262 -0.992382
# 4 -0.928381 -1.513088 -1.155864 -0.970612

# %% [markdown]
# # 6. Separación de los datos en grupos

# %%
# Llamamos al algoritmo y lo ejecutamos  para 1 cluster
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters = 1, init = 'k-means++', random_state = 42, n_init='auto')
kmeans.fit(df_standardized)
# Valor de WCSS
kmeans.inertia_
# Out:
# 128.00000000000003

# %% [markdown]
# # 7. Método del codo

# %%
# Se obtienen los diferentes valores de WCSS 
wcss = []
for i in range(1, 13):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42, n_init='auto')
    kmeans.fit(df_standardized)
    wcss.append(kmeans.inertia_)

# %%
wcss
# Out:
# [128.00000000000003,
#  71.65969327653953,
#  46.0790946467882,
#  38.02085292761427,
#  31.825343019003192,
#  29.03087868899268,
#  18.834888928624416,
#  17.436705870135405,
#  14.552449921928353,
#  11.46764125639452,
#  9.243196004257808,
#  8.072679022505051]

# %%
# Grafica de los valores de WCSS 
plt.figure(figsize=(10, 8))
plt.plot(range(1, 13), wcss,"go--")
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %% [markdown]
# # 7.1 Método Silhouette

# %%
from sklearn.metrics import silhouette_score

# %%
silhouette_score(df_standardized,  kmeans.labels_)
# Out:
# 0.3487847700946626

# %%
kmeans.labels_
# Out:
# array([ 5,  2,  6,  4,  4,  7,  5,  2,  5,  7,  3,  0,  8,  9,  9, 10,  8,
#         4, 11,  0,  0,  6,  1, 11,  8,  3,  8,  0,  4,  0,  4,  2],
#       dtype=int32)

# %%
#creamos una lista de modelos de K-Means de un determinado número de clusters llamado kmeans2_sil
kmeans2_sil= [KMeans(n_clusters=i, random_state=42, init='k-means++', n_init='auto').fit(df_standardized) for i in range(1,13)]

#calculamos el silhouette score a cada modelo (de diferente número de clusters)
sil_values = [ silhouette_score(df_standardized, model.labels_, random_state=11)
                    for model in kmeans2_sil[1:]
                   ]
#Guardamos los valores de los coeficientes en un arreglo de numpy
sil_values = np.array( sil_values )
sil_values
# Out:
# array([0.37464155, 0.33046133, 0.31613405, 0.31102337, 0.30876654,
#        0.39165478, 0.31905632, 0.32215614, 0.34189452, 0.35893323,
#        0.34878477])

# %%
plt.figure( figsize=(10.5,6)       )

plt.plot(range(2, 13), sil_values,
         linestyle = ':', linewidth = 1.5,
         marker = 'o', markersize = 10,
         color = '#2F968B' ,
         label = 'The Silhoutte Method'
        )

#Maquillar la gráfica
plt.title('The Silhouette Method', size = 25, pad = 10)
plt.xlabel('Number of clusters', size = 20)
plt.ylabel('Silhoutte Coefficent', size = 20)
plt.tick_params( labelsize = 15 )

plt.grid(linestyle = 'dashed', alpha = 0.5 )

plt.show()

# %%
print( 'El valor máximo es:', sil_values[ np.argmax(sil_values) ] )
print( 'El número óptimo de clusters es:', np.argmax(sil_values) + 1 + 1 )
# Out:
# El valor máximo es: 0.3916547843812458
# El número óptimo de clusters es: 7

# %%
fig , ax1 = plt.subplots( figsize = (10.5,6) )

ax1.set_title('Elbow Method and Silhouette Method', size = 20, pad = 10 )
#--------------- WCSS -----------------
ax1.plot( range(2,13), wcss[1:],
         linestyle = '--', linewidth = 1.5,
         marker = 'P', markersize = 10,
         color = '#C83E4D' ,
         label = 'The Elbow Method'
        )

#----------- optimal number of clusters -----------------

ax1.set_xlabel( 'Number of clusters', size = 15 )
ax1.set_ylabel('WCSS', size = 15 )
ax1.tick_params( axis = 'x', labelsize = 12 )
ax1.tick_params( axis = 'y', labelsize = 12 )

plt.legend(loc='upper left', prop = {'size':12})


# ------------- silhoutte coeff -------------
ax2 = ax1.twinx()
ax2.plot( range(2,13), sil_values,
         linestyle = ':', linewidth = 1.5,
         marker = 'o', markersize = 10,
         color = '#2F968B' ,
         label = 'The Silhouette Method'
        )

ax2.set_ylabel( '\nSilhoutte Coefficent', size = 15 )
ax2.tick_params( axis = 'y', labelsize = 12 )
plt.legend(loc='upper right', prop = {'size':12})


ax1.grid(  linestyle = 'dashed', alpha = 0.5 )

plt.show()

# %% [markdown]
# Se observa que con el método Silhouette se tiene un máximo con siete clusters, esto está confirmado  por el método Elbow, donde el último cambio importante está precisamente en 7 clusters. Se trabajará con 7 clusters.

# %% [markdown]
# # 7. Análisis de resultados

# %%
# Predicción de etiquetas
kmeans = KMeans(n_clusters = 7, init = 'k-means++', random_state = 42, n_init='auto')
y_kmeans = kmeans.fit_predict(df_standardized)
y_kmeans
# Out:
# array([3, 2, 3, 0, 0, 5, 3, 2, 3, 5, 4, 6, 6, 1, 1, 4, 6, 0, 3, 6, 6, 3,
#        1, 3, 6, 4, 6, 6, 0, 6, 0, 2], dtype=int32)

# %%
# Cambiamos los valores de los grupos para comenzar en 1 y lo agregamos al dataframe original
df['cluster'] = y_kmeans + 1
df.head()
# Out:
#                      Homicidio  Delitos_con_violencia  \
# Estados
# AGUASCALIENTES           1.368                  3.167
# BAJA CALIFORNIA          5.000                  3.296
# BAJA CALIFORNIA SUR      1.554                  3.411
# CAMPECHE                 1.533                  1.223
# CHIAPAS                  1.544                  1.444
#
#                      Delitos_con_armas_fuego  Delincuencia_organizada  \
# Estados
# AGUASCALIENTES                         1.490                    3.425
# BAJA CALIFORNIA                        5.000                    5.000
# BAJA CALIFORNIA SUR                    1.274                    5.000
# CAMPECHE                               1.345                    1.723
# CHIAPAS                                1.372                    1.629
#
#                      Carcel_Sin_sentencia  Impacto_economico_de_la_violencia  \
# Estados
# AGUASCALIENTES                      1.307                               51.9
# BAJA CALIFORNIA                     2.110                              259.6
# BAJA CALIFORNIA SUR                 1.496                               28.8
# CAMPECHE                            4.297                               21.6
# CHIAPAS                             2.874                               78.7
#
#                     Impacto_economico_per_capita_de_la_violencia  porcen_pib  \
# Estados
# AGUASCALIENTES                                            36,158        14.5
# BAJA CALIFORNIA                                           71,413        31.5
# BAJA CALIFORNIA SUR                                       35,761        13.4
# CAMPECHE                                                  21,543         2.2
# CHIAPAS                                                   13,742        17.8
#
#                      id  cluster
# Estados
# AGUASCALIENTES       AS        4
# BAJA CALIFORNIA      BC        3
# BAJA CALIFORNIA SUR  BS        4
# CAMPECHE             CC        1
# CHIAPAS              CS        1

# %%
# Observamos la distribución de grupos en un par de variables
plt.figure(figsize=(6,6))
sn.scatterplot(x='Homicidio', y = 'Delitos_con_violencia', hue='cluster',  
               palette=sn.color_palette("Set2")[:7] , data=df, s=200)
# Out:
# <Axes: xlabel='Homicidio', ylabel='Delitos_con_violencia'>

# %%
# #Comparando a pares las variables
sn.pairplot(df[atributos + ['cluster']], hue="cluster",  palette=sn.color_palette("Set2")[:7],height=1.7 , aspect=1)
plt.show()
# Out:
# /home/manuel/.pyenv/versions/3.11.4/envs/DS/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#Comparando los tres tipos de delitos

#%matplotlib notebook
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.colors

fig = plt.figure(figsize=(8, 6))
#ax = Axes3D(fig)
ax = fig.add_subplot(projection='3d')

x = df['Homicidio']
y = df['Delitos_con_violencia']
z = df['Delincuencia_organizada']
colors = df['cluster']
cmap = matplotlib.colors.ListedColormap(['blue','green','orange','red'])
g=ax.scatter(x, y, z, s=50,  c =  colors  , cmap=cmap  )

ax.set_xlabel('Homicidio')
ax.set_ylabel('Delitos_con_violencia')
ax.set_zlabel('Delincuencia_organizada')

legend = ax.legend(*g.legend_elements(), loc="lower center", title="Cluster", borderaxespad=-10, ncol=4)
ax.add_artist(legend)
#ax.view_init(elev=20, azim=35, roll=0)


plt.show()

# %%
# Se define un dataframe para mostrar la informacion en un mapa
df_map  = df
df_map.head()
# Out:
#                      Homicidio  Delitos_con_violencia  \
# Estados
# AGUASCALIENTES           1.368                  3.167
# BAJA CALIFORNIA          5.000                  3.296
# BAJA CALIFORNIA SUR      1.554                  3.411
# CAMPECHE                 1.533                  1.223
# CHIAPAS                  1.544                  1.444
#
#                      Delitos_con_armas_fuego  Delincuencia_organizada  \
# Estados
# AGUASCALIENTES                         1.490                    3.425
# BAJA CALIFORNIA                        5.000                    5.000
# BAJA CALIFORNIA SUR                    1.274                    5.000
# CAMPECHE                               1.345                    1.723
# CHIAPAS                                1.372                    1.629
#
#                      Carcel_Sin_sentencia  Impacto_economico_de_la_violencia  \
# Estados
# AGUASCALIENTES                      1.307                               51.9
# BAJA CALIFORNIA                     2.110                              259.6
# BAJA CALIFORNIA SUR                 1.496                               28.8
# CAMPECHE                            4.297                               21.6
# CHIAPAS                             2.874                               78.7
#
#                     Impacto_economico_per_capita_de_la_violencia  porcen_pib  \
# Estados
# AGUASCALIENTES                                            36,158        14.5
# BAJA CALIFORNIA                                           71,413        31.5
# BAJA CALIFORNIA SUR                                       35,761        13.4
# CAMPECHE                                                  21,543         2.2
# CHIAPAS                                                   13,742        17.8
#
#                      id  cluster
# Estados
# AGUASCALIENTES       AS        4
# BAJA CALIFORNIA      BC        3
# BAJA CALIFORNIA SUR  BS        4
# CAMPECHE             CC        1
# CHIAPAS              CS        1

# %%
# Información geográfica de México
estados_geo='datos/estadosGEO_mx.json'

# %%
# Librería Python que permite crear mapas interactivos 
import folium
import branca.colormap as cm
colormap = cm.LinearColormap(['#9b5fe0','#16a4d8','#60dbe8','#8bd346','#efdf48','#f9a52c', '#d64e12'], vmin=0.5, vmax=7.5).to_step(7)
colormap
# Out:
# <svg height="40" width="450"><line x1="0" y1="15" x2="0" y2="27" style="stroke:#9b5fe0ff;stroke-width:2;" /><line x1="1" y1="15" x2="1" y2="27" style="stroke:#9b5fe0ff;stroke-width:2;" /><line x1="2" y1="15" x2="2" y2="27" style="stroke:#9b5fe0ff;stroke-width:2;" /><line x1="3" y1="15" x2="3" y2="27" style="stroke:#9b5fe0ff;stroke-width:2;" /><line x1="4" y1="15" x2="4" y2="27" style="stroke:#9b5fe0ff;stroke-width:2;" /><line x1="5" y1="15" x2="5" y2="27" style="stroke:#9b5fe0ff;stroke-width:2;" /><line x1="6" y1="15" x2="6" y2="27" style="stroke:#9b5fe0ff;stroke-width:2;" /><line x1="7" y1="15" x2="7" y2="27" style="stroke:#9b5fe0ff;stroke-width:2;" /><line x1="8" y1="15" x2="8" y2="27" style="stroke:#9b5fe0ff;stroke-width:2;" /><line x1="9" y1="15" x2="9" y2="27" style="stroke:#9b5fe0ff;stroke-width:2;" /><line x1="10" y1="15" x2="10" y2="27" style="stroke:#9b5fe0ff;stroke-width:2;" /><line x1="11" y1="15" x2="11" y2="27" style="stroke:#9b5fe0ff;stroke-width:2;" /><line x1="12" y1="15" x2="12" y2="27" style="stroke:#9b5fe0ff;stroke-width:2;" /><line x1="13" y1="15" x2="13" y2="27" style="stroke:#9b5fe0ff;stroke-width:2;" /><line x1="14" y1="15" x2="14" y2="27" style="stroke:#9b5fe0ff;stroke-width:2;" /><line x1="15" y1="15" x2="15" y2="27" style="stroke:#9b5fe0ff;stroke-width:2;" /><line x1="16" y1="15" x2="16" y2="27" style="stroke:#9b5fe0ff;stroke-width:2;" /><line x1="17" y1="15" x2="17" y2="27" style="stroke:#9b5fe0ff;stroke-width:2;" /><line x1="18" y1="15" x2="18" y2="27" style="stroke:#9b5fe0ff;stroke-width:2;" /><line x1="19" y1="15" x2="19" y2="27" style="stroke:#9b5fe0ff;stroke-width:2;" /><line x1="20" y1="15" x2="20" y2="27" style="stroke:#9b5fe0ff;stroke-width:2;" /><line x1="21" y1="15" x2="21" y2="27" style="stroke:#9b5fe0ff;stroke-width:2;" /><line x1="22" y1="15" x2="22" y2="27" style="stroke:#9b5fe0ff;stroke-width:2;" /><line x1="23" y1="15" x2="23" y2="27" style="stroke:#9b5fe0ff;stroke-width:2;" /><line x1="24" y1="15" x2="24" y2="27" style="stroke:#9b5fe0ff;stroke-width:2;" /><line x1="25" y1="15" x2="25" y2="27" style="stroke:#9b5fe0ff;stroke-width:2;" /><line x1="26" y1="15" x2="26" y2="27" style="stroke:#9b5fe0ff;stroke-width:2;" /><line x1="27" y1="15" x2="27" y2="27" style="stroke:#9b5fe0ff;stroke-width:2;" /><line x1="28" y1="15" x2="28" y2="27" style="stroke:#9b5fe0ff;stroke-width:2;" /><line x1="29" y1="15" x2="29" y2="27" style="stroke:#9b5fe0ff;stroke-width:2;" /><line x1="30" y1="15" x2="30" y2="27" style="stroke:#9b5fe0ff;stroke-width:2;" /><line x1="31" y1="15" x2="31" y2="27" style="stroke:#9b5fe0ff;stroke-width:2;" /><line x1="32" y1="15" x2="32" y2="27" style="stroke:#9b5fe0ff;stroke-width:2;" /><line x1="33" y1="15" x2="33" y2="27" style="stroke:#9b5fe0ff;stroke-width:2;" /><line x1="34" y1="15" x2="34" y2="27" style="stroke:#9b5fe0ff;stroke-width:2;" /><line x1="35" y1="15" x2="35" y2="27" style="stroke:#9b5fe0ff;stroke-width:2;" /><line x1="36" y1="15" x2="36" y2="27" style="stroke:#9b5fe0ff;stroke-width:2;" /><line x1="37" y1="15" x2="37" y2="27" style="stroke:#9b5fe0ff;stroke-width:2;" /><line x1="38" y1="15" x2="38" y2="27" style="stroke:#9b5fe0ff;stroke-width:2;" /><line x1="39" y1="15" x2="39" y2="27" style="stroke:#9b5fe0ff;stroke-width:2;" /><line x1="40" y1="15" x2="40" y2="27" style="stroke:#9b5fe0ff;stroke-width:2;" /><line x1="41" y1="15" x2="41" y2="27" style="stroke:#9b5fe0ff;stroke-width:2;" /><line x1="42" y1="15" x2="42" y2="27" style="stroke:#9b5fe0ff;stroke-width:2;" /><line x1="43" y1="15" x2="43" y2="27" style="stroke:#9b5fe0ff;stroke-width:2;" /><line x1="44" y1="15" x2="44" y2="27" style="stroke:#9b5fe0ff;stroke-width:2;" /><line x1="45" y1="15" x2="45" y2="27" style="stroke:#9b5fe0ff;stroke-width:2;" /><line x1="46" y1="15" x2="46" y2="27" style="stroke:#9b5fe0ff;stroke-width:2;" /><line x1="47" y1="15" x2="47" y2="27" style="stroke:#9b5fe0ff;stroke-width:2;" /><line x1="48" y1="15" x2="48" y2="27" style="stroke:#9b5fe0ff;stroke-width:2;" /><line x1="49" y1="15"  ...

# %%
id_dict = df.set_index("id")["cluster"]

id_dict["BC"]
# Out:
# 3

# %%
map = folium.Map(location=[24, -102], tiles='cartodbpositron',zoom_start=5)

color_dict = {key: colormap(id_dict[key]) for key in id_dict.keys()}
# folium.GeoJson(estados_geo).add_to(map)


# folium.Choropleth(geo_data=estados_geo, data=df_map, # geo_path=country_geo, data=plot_data,
#              columns=['id', 'cluster'],
#              key_on='feature.id',
#              fill_color=linear, fill_opacity=0.9, line_opacity=0.9
#                  ).add_to(map)
# map

folium.GeoJson(
    estados_geo,
    style_function=lambda feature: {
        'fillColor': color_dict[feature["id"]],
        "color": "black",
        "weight": 1,
        "dashArray": "5, 5",
        "fillOpacity": 0.9,
        }
    ).add_to(map)

colormap.caption = "Grupo"
colormap.add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d5b54d4d0713805271f716ff0a6a969f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d5b54d4d0713805271f716ff0a6a969f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d5b54d4d0713805271f716ff0a6a969f = L.map(
#                 &quot;map_d5b54d4d0713805271f716ff0a6a969f&quot;,
#                 {
#                     center: [24.0, -102.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3344a2800e4fc19ab35f01390979eb89 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d5b54d4d0713805271f716ff0a6a969f);
#
#
#         function geo_json_55051fd05aecc1a9295dfd1fb29fa715_styler(feature) {
#             switch(feature.id) {
#                 case &quot;BC&quot;: case &quot;ZS&quot;: case &quot;CM&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;fillColor&quot;: &quot;#60dbe8ff&quot;, &quot;fillOpacity&quot;: 0.9, &quot;weight&quot;: 1};
#                 case &quot;BS&quot;: case &quot;CL&quot;: case &quot;DG&quot;: case &quot;NL&quot;: case &quot;SP&quot;: case &quot;AS&quot;: case &quot;QT&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;fillColor&quot;: &quot;#8bd346ff&quot;, &quot;fillOpacity&quot;: 0.9, &quot;weight&quot;: 1};
#                 case &quot;CH&quot;: case &quot;GT&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;fillColor&quot;: &quot;#f9a52cff&quot;, &quot;fillOpacity&quot;: 0.9, &quot;weight&quot;: 1};
#                 case &quot;SR&quot;: case &quot;MN&quot;: case &quot;GR&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;fillColor&quot;: &quot;#efdf48ff&quot;, &quot;fillOpacity&quot;: 0.9, &quot;weight&quot;: 1};
#                 case &quot;NT&quot;: case &quot;CC&quot;: case &quot;TL&quot;: case &quot;CS&quot;: case &quot;YN&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;fillColor&quot;: &quot;#9b5fe0ff&quot;, &quot;fillOpacity&quot;: 0.9, &quot;weight&quot;: 1};
#                 case &quot;DF&quot;: case &quot;MC&quot;: case &quot;QR&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;fillColor&quot;: &quot;#16a4d8ff&quot;, &quot;fillOpacity&quot;: 0.9, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;fillColor&quot;: &quot;#d64e12ff&quot;, &quot;fillOpacity&quot;: 0.9, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_55051fd05aecc1a9295dfd1fb29fa715_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_55051fd05aecc1a9295dfd1fb29fa715 = L.geoJson(null, {
#                 onEachFeature: geo_json_55051fd05aecc1a9295dfd1fb29fa715_onEachFeature,
#
#                 style: geo_json_55051fd05aecc1a9295dfd1fb29fa715_styler,
#         });
#
#         function geo_json_55051fd05aecc1a9295dfd1fb29fa715_add (data) {
#             geo_json_55051fd05aecc1a9295dfd1fb29fa715
#                 .addData(data)
#                 .addTo(map_d5b54d4d0713805271f716ff0a6a969f);
#         }
#             geo_json_55051fd05aecc1a9295dfd1fb29fa715_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[[-114.14749989661378, 28.00015380734409], [-114.20702063689639, 27.999986070150626], [-114.13438880099996, 28.083929755000057], [-114.1171839079999, 28.04317994200001], [-114.14749989661378, 28.00015380734409]]], [[[-115.18304013799988, 28.095147119000117], [-115.18828828499997, 28.056346964000014], [-115.22814296399993, 28.028322673000147], [-115.26184529499996, 28.070143449000156], [-115.33400439999991, 28.124877560000144], [-115.23975583999996, 28.233606330000114], [-115.2624534249999, 28.29875638300014], [-115.24864245299992, 28.359315181000127], [-115.21486747199992, 28.378279134000152], [-115.16271472199992, 28.261342294000045], [-115.1722683749999, 28.21264516900014], [-115.15548988699996, 28.17070354000016], [-115.18304013799988, 28.095147119000117]]], [[[-112.55745077799986, 28.73380926900002], [-112.55393926599993, 28.672288046000

# %%
sn.pairplot(df[atributos + ['cluster']], hue="cluster",  palette=sn.color_palette("Set2")[:7],height=1.7 , aspect=1)
plt.show()
# Out:
# /home/manuel/.pyenv/versions/3.11.4/envs/DS/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ## Observaciones

# %% [markdown]
# Grupo 1 (morado): La región del Sureste y algunos estados en el centro se caracterizan por tener bajos índices delictivos.
#
# Grupo 2 (azul fuerte): Quintana Roo, CDMX y Estado de México. Tiene valores promedio en delito con armas de fuego y en homicidios, pero tienen altos índices y delincuencia organizada.
#
# Grupo 3 (azul claro): Tiene altos índices de homicidios, delincuencia organizada y delitos con armas de fuego, y un índice en delitos con violencia en 2.5.
#
# Grupo 4 (verde): Índice de homicidio y delitos con armas de fuego en 2. Alta delincuencia organizada y un índice de delitos con violencia en 2.5
#
# Grupo 5 (amarillo): Índice de homicidio de 4, delitos con violencia de 2, delincuencia organizada de 2.5 y delitos con armas de fuego de 3.
#
# Grupo 6 (naranja): Altos índices de homicidio y delitos con armas de fuego. Delitos con violencia y delincuencia organizada de 2.5
#
# Grupo 7 (rojo-cafe): Todos los índices están entre 2 y 2.75, aproximadamente.

# %% [markdown]
# ## Conclusiones

# %% [markdown]
# Con el método Silhoutte se obtuvo de manera óptima el número de clusters a elegir. Se puede observar que los 7 clusters sí tienen relación que describe de manera general al estado en cuestión. Se puede observar que los clusters sí se agrupan por regiones en el mapa de México (no en todos los casos), por lo que hay una relación geográfica o social de cada grupo.
