# %% [markdown]
# # Caso de estudio

# %% [markdown]
# Analizar con herramientas de pandas las bases de datos:
# * Covid
# * Incendios
# * Escuelas de Jalisco
# * Juegos olimpicos
# * Indicador de pobreza

# %%
import pandas as pd

# %% [markdown]
# ## Covid

# %%
df_covid = pd.read_csv('Datos/Covid_2020/200419COVID19MEXICO.csv')
df_covid.head()
# Out:
#   FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  SEXO  \
# 0          2020-04-19      09e8dc       2       9          15     1
# 1          2020-04-19      1dd782       2      12           9     1
# 2          2020-04-19      0efbaf       2       9          28     2
# 3          2020-04-19      0e8ab4       2      12           9     2
# 4          2020-04-19      013a6c       1       3          15     2
#
#    ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  ... CARDIOVASCULAR  \
# 0           15           15           37.0              2  ...              2
# 1           15            9            3.0              1  ...              2
# 2           16           28           32.0              1  ...              2
# 3           99            9           13.0              1  ...              2
# 4           15           15          106.0              1  ...              2
#
#   OBESIDAD RENAL_CRONICA  TABAQUISMO  OTRO_CASO  RESULTADO  MIGRANTE  \
# ...

# %%
df_covid.dtypes
# Out:
# FECHA_ACTUALIZACION     object
# ID_REGISTRO             object
# ORIGEN                   int64
# SECTOR                   int64
# ENTIDAD_UM               int64
# SEXO                     int64
# ENTIDAD_NAC              int64
# ENTIDAD_RES              int64
# MUNICIPIO_RES          float64
# TIPO_PACIENTE            int64
# FECHA_INGRESO           object
# FECHA_SINTOMAS          object
# FECHA_DEF               object
# INTUBADO                 int64
# NEUMONIA                 int64
# EDAD                     int64
# NACIONALIDAD             int64
# EMBARAZO                 int64
# HABLA_LENGUA_INDIG       int64
# DIABETES                 int64
# EPOC                     int64
# ASMA                     int64
# INMUSUPR                 int64
# HIPERTENSION             int64
# OTRA_COM                 int64
# CARDIOVASCULAR           int64
# OBESIDAD                 int64
# RENAL_CRONICA            int64
# TABAQUISMO               int64
# OTRO_CASO                int64
# ...

# %%
df_covid.describe()
# Out:
#              ORIGEN        SECTOR    ENTIDAD_UM          SEXO   ENTIDAD_NAC  \
# count  49570.000000  49570.000000  49570.000000  49570.000000  49570.000000
# mean       1.603248      8.602522     14.712124      1.490337     35.098971
# std        0.489229      3.802911      8.122476      0.499912     34.728889
# min        1.000000      1.000000      1.000000      1.000000      1.000000
# 25%        1.000000      4.000000      9.000000      1.000000     14.000000
# 50%        2.000000     12.000000     14.000000      1.000000     19.000000
# 75%        2.000000     12.000000     20.000000      2.000000     30.000000
# max        2.000000     13.000000     32.000000      2.000000     99.000000
#
#         ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE      INTUBADO      NEUMONIA  \
# count  49570.000000   49561.000000   49570.000000  49570.000000  49570.000000
# mean      14.919205      35.851254       1.236232     74.555094      1.857051
# ...

# %% [markdown]
# ### Análisis 1

# %% [markdown]
# ### Análisis 2

# %% [markdown]
# ### Análisis 3

# %% [markdown]
# ### Análisis 4

# %% [markdown]
# ### Análisis 5

# %% [markdown]
# ## Incendios

# %%
# df_incendios = pd.read_csv('Datos/Incendios/BD_IncendiosSNIF_2015-2022.csv', encoding='latin-1')
df_incendios = pd.read_csv('Datos/Incendios/Historico_IncendiosForestales_1970-2022.csv')
df_incendios
# Out:
#      Gerencia De Manejo del Fuego, Diciembre 2022          Unnamed: 1  \
# 0                                             Año  Entidad Federativa
# 1                                            1970           Chihuahua
# 2                                            1970             Chiapas
# 3                                            1970          Guanajuato
# 4                                            1970              México
# ...                                           ...                 ...
# 1692                                         2022          Tamaulipas
# 1693                                         2022            Tlaxcala
# 1694                                         2022            Veracruz
# 1695                                         2022             Yucatán
# 1696                                         2022           Zacatecas
#
#                             Unnamed: 2                Unnamed: 3 Unnamed: 4
# ...

# %%
df_incendios.dtypes
# Out:
# Gerencia De Manejo del Fuego, Diciembre 2022    object
# Unnamed: 1                                      object
# Unnamed: 2                                      object
# Unnamed: 3                                      object
# Unnamed: 4                                      object
# dtype: object

# %%
df_incendios.describe()
# Out:
#        Gerencia De Manejo del Fuego, Diciembre 2022 Unnamed: 1 Unnamed: 2  \
# count                                          1697       1697       1697
# unique                                           54         33        542
# top                                            1996    Hidalgo          0
# freq                                             32         53         49
#
#        Unnamed: 3 Unnamed: 4
# count        1697       1697
# unique       1511          7
# top             0     Centro
# freq           49        530

# %% [markdown]
# ### Análisis 1

# %% [markdown]
# ### Análisis 2

# %% [markdown]
# ### Análisis 3

# %% [markdown]
# ### Análisis 4

# %% [markdown]
# ### Análisis 5

# %% [markdown]
# ## Escuelas de Jalisco

# %%
df_escuelas = pd.read_csv('Datos/EscuelasJalisco/cct_estadistica.csv', encoding='latin-1')
df_escuelas.head()
# Out:
#      CLAVE CT                    NOM TURNO                  NOMBRE CT  \
# 0  14DPR3480S                   VESPERTINO  MIGUEL HIDALGO Y COSTILLA
# 1  14DPR2780I                     MATUTINO        CONSTITUCION DEL 57
# 2  14DPR1553G  CONTINUO (JORNADA AMPLIADA)  MIGUEL HIDALGO Y COSTILLA
# 3  14SES0104Q                     MATUTINO               NIOS HEROES
# 4  14EJN0826I                   VESPERTINO        EVA GONZALEZ BLANCO
#
#                         DOMICILIO  LOCALIDAD INEGI       NOMBRE LOCALIDAD  \
# 0                    RIO SANTIAGO                1        TIZAPAN EL ALTO
# 1                        CONOCIDO               54         MESA DE MENDEZ
# 2                        CONOCIDO               31                DOLORES
# 3              ALVARO OBREGON 115              280  SANTA MARIA DEL VALLE
# 4  MARCELINO GARCIA BARRAGAN 1954                1            GUADALAJARA
#
#   NOMBRE COLONIA  MUNICIPIO NOMBRE MUNICIPIO SOSTENIMIENTO  ... DOCENTES  \
# ...

# %%
df_escuelas.dtypes
# Out:
# CLAVE CT                                  object
# NOM TURNO                                 object
# NOMBRE CT                                 object
# DOMICILIO                                 object
# LOCALIDAD INEGI                            int64
#  NOMBRE LOCALIDAD                         object
# NOMBRE COLONIA                            object
# MUNICIPIO                                  int64
# NOMBRE MUNICIPIO                          object
# SOSTENIMIENTO                             object
# NIVEL                                     object
# PROGRAMA                                  object
# HOMBRES 1¡                                 int64
# MUJERES 1¡                                 int64
# TOTAL 1¡                                   int64
# HOMBRES 2¡                                 int64
# MUJERES 2¡                                 int64
# TOTAL 2¡                                   int64
# HOMBRES 3¡                                 int64
# ...

# %%
df_escuelas.describe()
# Out:
#        LOCALIDAD INEGI     MUNICIPIO    HOMBRES 1¡    MUJERES 1¡  \
# count     14018.000000  14018.000000  14018.000000  14018.000000
# mean         69.183621     68.894421     14.384292     13.736767
# std         373.026706     36.053656     27.833578     25.470229
# min           1.000000      1.000000      0.000000      0.000000
# 25%           1.000000     39.000000      0.000000      0.000000
# 50%           3.000000     67.000000      4.000000      4.000000
# 75%          51.000000     98.000000     16.000000     15.000000
# max        9503.000000    125.000000    773.000000    412.000000
#
#            TOTAL 1¡    HOMBRES 2¡    MUJERES 2¡      TOTAL 2¡    HOMBRES 3¡  \
# count  14018.000000  14018.000000  14018.000000  14018.000000  14018.000000
# mean      28.121059     17.870238     17.392852     35.263090     17.290555
# std       52.060523     24.878830     24.401495     48.270267     23.177131
# ...

# %% [markdown]
# ### Análisis 1

# %% [markdown]
# ### Análisis 2

# %% [markdown]
# ### Análisis 3

# %% [markdown]
# ### Análisis 4

# %% [markdown]
# ### Análisis 5

# %% [markdown]
# ## Juegos olimpicos

# %%
df_olimpiadas = pd.read_csv('Datos/Olimpiadas/athlete_events.csv')
df_olimpiadas.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
df_olimpiadas.dtypes
# Out:
# ID          int64
# Name       object
# Sex        object
# Age       float64
# Height    float64
# Weight    float64
# Team       object
# NOC        object
# Games      object
# Year        int64
# Season     object
# City       object
# Sport      object
# Event      object
# Medal      object
# dtype: object

# %%
df_olimpiadas.describe()
# Out:
#                   ID            Age         Height         Weight  \
# count  271116.000000  261642.000000  210945.000000  208241.000000
# mean    68248.954396      25.556898     175.338970      70.702393
# std     39022.286345       6.393561      10.518462      14.348020
# min         1.000000      10.000000     127.000000      25.000000
# 25%     34643.000000      21.000000     168.000000      60.000000
# 50%     68205.000000      24.000000     175.000000      70.000000
# 75%    102097.250000      28.000000     183.000000      79.000000
# max    135571.000000      97.000000     226.000000     214.000000
#
#                 Year
# count  271116.000000
# mean     1978.378480
# std        29.877632
# min      1896.000000
# 25%      1960.000000
# 50%      1988.000000
# 75%      2002.000000
# max      2016.000000

# %% [markdown]
# ### Análisis 1

# %% [markdown]
# ### Análisis 2

# %% [markdown]
# ### Análisis 3

# %% [markdown]
# ### Análisis 4

# %% [markdown]
# ### Análisis 5

# %% [markdown]
# ## Indicador de pobreza

# %%
df_pobreza = pd.read_csv('Datos/Pobreza/rangos_pobreza_loc_urbana_2020.csv')
df_pobreza.head()
# Out:
#    clave_entidad entidad_federativa  clave_municipio       municipio  \
# 0              1     Aguascalientes             1001  Aguascalientes
# 1              1     Aguascalientes             1001  Aguascalientes
# 2              1     Aguascalientes             1001  Aguascalientes
# 3              1     Aguascalientes             1001  Aguascalientes
# 4              1     Aguascalientes             1001  Aguascalientes
#
#    clave_localidad                                          localidad  \
# 0         10010001                                     Aguascalientes
# 1         10010237                                          Jaltomate
# 2         10010239  General José María Morelos y Pavón (Cañada Honda)
# 3         10010293                              Norias de Ojocaliente
# 4         10010357                              Norias del Paso Hondo
#
#    poblacionITER rango_pobreza
# 0         863893      [20, 40)
# 1           2805      [40, 60)
# 2           3822      [20, 40)
# ...

# %%
df_pobreza.dtypes
# Out:
# clave_entidad          int64
# entidad_federativa    object
# clave_municipio        int64
# municipio             object
# clave_localidad        int64
# localidad             object
# poblacionITER          int64
# rango_pobreza         object
# dtype: object

# %%
df_pobreza.describe()
# Out:
#        clave_entidad  clave_municipio  clave_localidad  poblacionITER
# count    5242.000000      5242.000000     5.242000e+03   5.242000e+03
# mean       18.309042     18390.839184     1.839084e+08   1.914164e+04
# std         7.352718      7367.063913     7.367062e+07   9.264570e+04
# min         1.000000      1001.000000     1.001000e+07   1.200000e+01
# 25%        14.000000     14034.250000     1.403425e+08   2.672000e+03
# 50%        18.000000     18006.500000     1.800650e+08   4.055000e+03
# 75%        22.000000     22016.000000     2.201600e+08   8.331750e+03
# max        32.000000     32058.000000     3.205800e+08   1.835486e+06

# %% [markdown]
# ### Análisis 1

# %% [markdown]
# ### Análisis 2

# %% [markdown]
# ### Análisis 3

# %% [markdown]
# ### Análisis 4

# %% [markdown]
# ### Análisis 5
