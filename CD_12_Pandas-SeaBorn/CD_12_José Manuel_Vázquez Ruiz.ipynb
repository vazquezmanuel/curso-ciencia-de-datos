# %% [markdown]
# <!--Información del curso-->
# <img align="left" style="padding-right:10px;" src="figuras/logo_ciencia_datos.png">

# %% [markdown]
# # Librerías
#
# Cargando las bibliotecas que necesitamos

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('dark_background')

# %% [markdown]
# ## Instrucciones

# %% [markdown]
#  1. Cada inciso podra resolverse con el estilo puramente de Pandas o Seaborn, no es necesario usar ambos
#  2. Puede agregar todas las opciones de visualización que crea convenientes

# %% [markdown]
# ## Ejercicio 1:  Datos de la estación meteorologica de Progreso, Yucatán
#
# Fuente:  https://smn.conagua.gob.mx/es/observando-el-tiempo/estaciones-meteorologicas-automaticas-ema-s

# %%
df= pd.read_csv("datos/Estacion_PROGRESO_90_dias_19Nov.csv")
df.head(5)
# Out:
#          FechaLocal          FechaUTC  TemperaturaAire(C)  Precipitacion(mm)  \
# 0  19/11/2020 15:20  19/11/2020 21:20                  28                  0
# 1  19/11/2020 15:10  19/11/2020 21:10                  28                  0
# 2  19/11/2020 15:00  19/11/2020 21:00                  28                  0
# 3  19/11/2020 14:50  19/11/2020 20:50                  28                  0
# 4  19/11/2020 14:40  19/11/2020 20:40                  28                  0
#
#    HumedadRelativa(%)  PresionAtmosferica(hpa)  RadiacionSolar(W/m2)  \
# 0                  72                   1017.0                 226.0
# 1                  73                   1017.0                 445.0
# 2                  74                   1017.0                 475.0
# 3                  75                   1017.0                 359.0
# 4                  74                   1017.0                 550.0
#
#    DireccionViento(grados)  RapidezViento(km/h)  DireccionRafaga(grados)  \
# 0                     59.0                 28.0                    115.0
# 1                     59.0                 27.0                    103.0
# 2                     60.0                 28.0                     97.0
# 3                     59.0                 27.0                     94.0
# 4                     63.0                 27.0                     99.0
#
#    RapidezRafaga(km/h)
# 0                 46.0
# 1                 43.0
# 2                 53.0
# 3                 51.0
# 4                 48.0

# %% [markdown]
# <div class="alert alert-success">
#
# a). Hacer una grafica de dispersión para la TemperaturaAire(C) y la HumedadRelativa(%)
#
# </div>

# %%
sns.jointplot(data=df, x = 'TemperaturaAire(C)', y = 'HumedadRelativa(%)' )

# %%
df.plot.scatter(x = 'TemperaturaAire(C)', y = 'HumedadRelativa(%)', figsize = (10, 5))
# Out:
# <Axes: xlabel='TemperaturaAire(C)', ylabel='HumedadRelativa(%)'>

# %% [markdown]
# <div class="alert alert-success">
#
# b). Hacer una grafica de dispersión comparando estas 4  columnas :  TemperaturaAire(C), la HumedadRelativa(%) , PresionAtmosferica(hpa)  y la	RadiacionSolar(W/m2)
#
# </div>

# %%
pd.plotting.scatter_matrix(df[['TemperaturaAire(C)', 'HumedadRelativa(%)', 'PresionAtmosferica(hpa)', 'RadiacionSolar(W/m2)']], figsize=(11,11))
# Out:
# array([[<Axes: xlabel='TemperaturaAire(C)', ylabel='TemperaturaAire(C)'>,
#         <Axes: xlabel='HumedadRelativa(%)', ylabel='TemperaturaAire(C)'>,
#         <Axes: xlabel='PresionAtmosferica(hpa)', ylabel='TemperaturaAire(C)'>,
#         <Axes: xlabel='RadiacionSolar(W/m2)', ylabel='TemperaturaAire(C)'>],
#        [<Axes: xlabel='TemperaturaAire(C)', ylabel='HumedadRelativa(%)'>,
#         <Axes: xlabel='HumedadRelativa(%)', ylabel='HumedadRelativa(%)'>,
#         <Axes: xlabel='PresionAtmosferica(hpa)', ylabel='HumedadRelativa(%)'>,
#         <Axes: xlabel='RadiacionSolar(W/m2)', ylabel='HumedadRelativa(%)'>],
#        [<Axes: xlabel='TemperaturaAire(C)', ylabel='PresionAtmosferica(hpa)'>,
#         <Axes: xlabel='HumedadRelativa(%)', ylabel='PresionAtmosferica(hpa)'>,
#         <Axes: xlabel='PresionAtmosferica(hpa)', ylabel='PresionAtmosferica(hpa)'>,
#         <Axes: xlabel='RadiacionSolar(W/m2)', ylabel='PresionAtmosferica(hpa)'>],
#        [<Axes: xlabel='TemperaturaAire(C)', ylabel='RadiacionSolar(W/m2)'>,
#         <Axes: xlabel='HumedadRelativa(%)', ylabel='RadiacionSolar(W/m2)'>,
#         <Axes: xlabel='PresionAtmosferica(hpa)', ylabel='RadiacionSolar(W/m2)'>,
#         <Axes: xlabel='RadiacionSolar(W/m2)', ylabel='RadiacionSolar(W/m2)'>]],
#       dtype=object)

# %%
sns.pairplot(df[['TemperaturaAire(C)', 'HumedadRelativa(%)', 'PresionAtmosferica(hpa)', 'RadiacionSolar(W/m2)']])
# Out:
# /home/manuel/.pyenv/versions/3.11.4/envs/DS/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# # Ejercicio 2: Incendios en México

# %%
df= pd.read_csv("datos/Serie_historica_anual_incendios_2017.csv")
df.head(5)
# Out:
#    Número de Incendio Clave del incendio Grados  Minutos  Segundos  Grados.1  \
# 0                 922         17-15-0922     19       26      45.7        98
# 1                  33         17-23-0033     21       12      21.8        86
# 2                 298         17-07-0298     16       25      53.1        93
# 3                  36         17-23-0036     19       14      47.3        88
# 4                 160         17-20-0160     16       36       4.0        97
#
#    Minutos.1  Segundos.1  Clave municipio        Estado  ...  \
# 0         46        23.0               99        México  ...
# 1         59        57.3                5  Quintana Roo  ...
# 2         56        38.5               17       Chiapas  ...
# 3         19        24.5                2  Quintana Roo  ...
# 4         44         6.0              377        Oaxaca  ...
#
#                   Tamaño Deteccion   Llegada Duracion HMS Duracion H  \
# 0  Mayor a 100 Hectáreas  00:00:00  00:00:00     00:00:00        0.0
# 1      21 a 50 Hectáreas  36:00:00  00:30:00     00:00:00        0.0
# 2  Mayor a 100 Hectáreas  00:30:00  00:30:00     00:00:00        0.0
# 3     51 a 100 Hectáreas  01:00:00  10:45:00     00:00:00        0.0
# 4  Mayor a 100 Hectáreas  02:00:00  07:00:00     00:00:00        0.0
#
#   Costos MXN Superficie Salvada CO2 emitido CO2 Evito emitir   Region
# 0  118726.00           39095.73    70852.06       1398996.49   Centro
# 1   55493.82             768.50     1457.05         22208.31  Sureste
# 2   49565.00            1981.46     6920.70        105485.34  Sureste
# 3   47800.52            1084.77        0.00             0.00  Sureste
# 4   42600.00            7697.21    18070.85        275435.96   Centro
#
# [5 rows x 37 columns]

# %% [markdown]
# <div class="alert alert-success">
#
# a). Utilizar una grafica de barras para mostrar el número de incendios registrados segun la columna 'Region',  para todos los datos registrados
#
# </div>

# %%
df.value_counts('Region').plot(kind = 'bar')
# Out:
# <Axes: xlabel='Region'>

# %%
sns.countplot(x = 'Region',  data = df)
# Out:
# <Axes: xlabel='Region', ylabel='count'>

# %% [markdown]
# <div class="alert alert-success">
#
# b). Utilizar una grafica de barras para mostrar el número de incendios registrados segun  la columna 'Duración días', para todos los datos registrados
#
# </div>

# %%
df['Duración días']
# Out:
# 0       4 a 7 Días
# 1       4 a 7 Días
# 2       4 a 7 Días
# 3       4 a 7 Días
# 4       4 a 7 Días
#            ...
# 8867         1 Día
# 8868         1 Día
# 8869         1 Día
# 8870         1 Día
# 8871    2 a 3 Días
# Name: Duración días, Length: 8872, dtype: object

# %%
df.value_counts('Duración días').plot(kind = 'bar')
# Out:
# <Axes: xlabel='Duración días'>

# %%
sns.countplot(x = 'Duración días',  data = df)
# Out:
# <Axes: xlabel='Duración días', ylabel='count'>

# %% [markdown]
# <div class="alert alert-success">
#
# c). Utilizar una grafica de Seaborn de dispersión para comparar las columnas 'Duracion H' y 'Total Hectareas', además deberá agregar la opción   hue="Mes Acontecimiento", para todos los datos registrados
#
# </div>

# %%
sns.jointplot(data=df, x = 'Duracion H', y = 'Total Hectareas', hue = 'Mes Acontecimiento')

# %% [markdown]
# <div class="alert alert-success">
#
# d). Utilizar una grafica de Seaborn de dispersión para comparar las columnas 'Duracion H' y 'Total Hectareas', además deberá agregar la opción   hue="Mes Acontecimiento", para  los datos de Yucatán registrados
#
# </div>

# %%
sns.jointplot(data=df[df['Estado'] == 'Yucatán'], x = 'Duracion H', y = 'Total Hectareas', hue = 'Mes Acontecimiento')

# %% [markdown]
# # Ejercicio 3: Información de Casas de California

# %% [markdown]
# Cargar el archivo **datos/info_Casas_SF.csv**, el cual contiene datos del  censo de California. Estos datos estan dados por  distritos en California. Los distritos son la unidad geográfica más pequeña para la cual la Oficina del Censo de los Estados Unidos publica datos de muestra (un grupo de bloques generalmente tiene una población de 600 a 3,000 personas).  Los datos son los siguientes
#
# 1. longitud: una medida de qué tan al oeste está una casa; un valor más alto está más al oeste
#
# 2. latitud: una medida de la distancia al norte de una casa; un valor más alto está más al norte
#
# 3. housingMedianAge: Edad promedio de una casa dentro de un distrito; un número menor es un edificio más nuevo
#
# 4. totalRooms: número total de habitaciones dentro de un distrito
#
# 5. totalBedrooms: número total de dormitorios dentro de un distrito
#
# 6. población: número total de personas que residen en un distrito
#
# 7. hogares: número total de hogares, un grupo de personas que residen dentro de una unidad de vivienda, para un distrito
#
# 8. ingreso medio: ingreso mediano de los hogares dentro de una cuadra de casas (medido en decenas de miles de dólares estadounidenses)
#
# 9. medianHouseValue: valor medio de la vivienda para los hogares dentro de un distrito (medido en dólares estadounidenses)
#
# 10. oceanProximity: Ubicación de la casa con respecto al oceano
#
# Fuente: https://www.kaggle.com/camnugent/california-housing-prices

# %% [markdown]
# <div class="alert alert-success">
#
# a). Utilizar 4 diferentes graficas para mostrar algunos parametros  del archivo datos/info_Casas_SF.csv
#
# </div>

# %%
df = pd.read_csv('datos/info_Casas_SF.csv')
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20635.000000  20635.000000        20635.000000  20635.000000
# mean    -119.569999     35.632412           28.636152   2636.020208
# std        2.003685      2.135918           12.583924   2181.794772
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1448.000000
# 50%     -118.500000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20428.000000  20635.000000  20635.000000   20635.000000
# mean       537.899305   1425.660286    499.593700       3.870944
# std        421.425970   1132.530137    382.357072       1.899961
# min          1.000000      3.000000      1.000000       0.499900
# 25%        296.000000    787.000000    280.000000       2.563100
# 50%        435.000000   1166.000000    409.000000       3.535200
# 75%        647.000000   1725.000000    605.000000       4.743700
# max       6445.000000  35682.000000   6082.000000      15.000100
#
#        median_house_value
# count        20635.000000
# mean        206813.756288
# std         115372.499511
# min          14999.000000
# 25%         119600.000000
# 50%         179700.000000
# 75%         264700.000000
# max         500001.000000

# %% [markdown]
# Gráfica de barras para la variable: proximidad del oceano

# %%
df['ocean_proximity'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='ocean_proximity'>

# %%
sns.countplot(x = 'ocean_proximity',  data = df)
# Out:
# <Axes: xlabel='ocean_proximity', ylabel='count'>

# %% [markdown]
# Gráfica de dispersión de la edad promedio de una casa y el valor promedio de dicha casa

# %%
df.plot.scatter(x = 'housing_median_age', y = 'median_house_value', c = 'households', figsize = (10, 5))
# Out:
# <Axes: xlabel='housing_median_age', ylabel='median_house_value'>

# %%
plot = sns.jointplot(data=df, x = 'housing_median_age', y = 'median_house_value', hue = 'households')
plot.ax_marg_x.set_xlim(0, 70)
plot.ax_marg_y.set_ylim(0, 500000)
plt.show()

# %% [markdown]
# Número de habitaciónes y de dormitorios, ordenando por el número de habitaciones

# %%
data = df.sort_values('total_rooms').reset_index()
data
# Out:
#        index  longitude  latitude  housing_median_age  total_rooms  \
# 0       3126    -117.79     35.21                 4.0          2.0
# 1      12281    -116.95     33.86                 1.0          6.0
# 2      16166    -122.50     37.79                52.0          8.0
# 3       5916    -118.44     34.28                46.0         11.0
# 4         73    -122.29     37.81                46.0         12.0
# ...      ...        ...       ...                 ...          ...
# 20630  12196    -117.20     33.58                 2.0      30450.0
# 20631   6057    -117.78     34.03                 8.0      32054.0
# 20632   9875    -121.79     36.64                11.0      32627.0
# 20633  10304    -117.74     33.89                 4.0      37937.0
# 20634  13134    -121.44     38.43                 3.0      39320.0
#
#        total_bedrooms  population  households  median_income  \
# 0                 2.0         6.0         2.0         2.3750
# 1                 2.0         8.0         2.0         1.6250
# 2                 1.0        13.0         1.0        15.0001
# 3                11.0        24.0        13.0         2.8750
# 4                 4.0        18.0         7.0         0.4999
# ...               ...         ...         ...            ...
# 20630          5033.0      9419.0      3197.0         4.5936
# 20631          5290.0     15507.0      5050.0         6.0191
# 20632          6445.0     28566.0      6082.0         2.3087
# 20633          5471.0     16122.0      5189.0         7.4947
# 20634          6210.0     16305.0      5358.0         4.9516
#
#        median_house_value ocean_proximity
# 0                137500.0          INLAND
# 1                 55000.0          INLAND
# 2                500001.0        NEAR BAY
# 3                162500.0       <1H OCEAN
# 4                 67500.0        NEAR BAY
# ...                   ...             ...
# 20630            174300.0       <1H OCEAN
# 20631            253900.0       <1H OCEAN
# 20632            118800.0       <1H OCEAN
# 20633            366300.0       <1H OCEAN
# 20634            153700.0          INLAND
#
# [20635 rows x 11 columns]

# %%
data[['total_rooms', 'total_bedrooms']].plot(figsize = (15, 5))
# Out:
# <Axes: >

# %%
sns.lineplot(data=data[['total_rooms', 'total_bedrooms']] , linewidth=2.5  )
# Out:
# <Axes: >

# %% [markdown]
# Histograma del ingreso mediano de los hogares

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20630    -121.09     39.48                25.0       1665.0           374.0
# 20631    -121.21     39.49                18.0        697.0           150.0
# 20632    -121.22     39.43                17.0       2254.0           485.0
# 20633    -121.32     39.43                18.0       1860.0           409.0
# 20634    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20630       845.0       330.0         1.5603             78100.0
# 20631       356.0       114.0         2.5568             77100.0
# 20632      1007.0       433.0         1.7000             92300.0
# 20633       741.0       349.0         1.8672             84700.0
# 20634      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20630          INLAND
# 20631          INLAND
# 20632          INLAND
# 20633          INLAND
# 20634          INLAND
#
# [20635 rows x 10 columns]

# %%
df['median_income'].plot(kind = 'hist', bins = 25, alpha=0.65)
# Out:
# <Axes: ylabel='Frequency'>

# %%
sns.histplot(data=df['median_income'], element="step")
# Out:
# <Axes: xlabel='median_income', ylabel='Count'>
