# %% [markdown]
# <!--Información del curso-->
# <img align="left" style="padding-right:10px;" src="figuras/logo_ciencia_datos.png">

# %% [markdown]
# <center><h1 style="font-size:2em;color:#2467C0"> Pandas - Parte 4  </h1></center>
#
# <center><h4 style="font-size:2em;color:#840700">  Pandas - Combinación de DataFrames     </h4></center>
#
# <br>
# <table>
# <col width="550">
# <col width="450">
# <tr>
# <td><img src="figuras/concatenar.png" align="left" style="width:500px"/></td>
# <td>
#
# * **Wes McKinney**, empezó a desarrollar Pandas en el año 2008 mientras trabajaba en *AQR Capital* por la necesidad que tenía de una herramienta flexible de alto rendimiento para realizar análisis cuantitativo en datos financieros.
# * Antes de dejar AQR convenció a la administración de la empresa de distribuir esta biblioteca bajo licencia de código abierto.
# * **Pandas** es un acrónimo de **PANel DAta analysiS**
#
#
# <br>
# </td>
# </tr>
# </table>

# %% [markdown]
# # Introducción

# %% [markdown]
# Algunos de los estudios de datos más interesantes provienen de la combinación de diferentes fuentes de datos.
# Estas operaciones pueden involucrar desde la concatenación muy sencilla de dos conjuntos de datos diferentes, hasta uniones y fusiones de estilo de base de datos complejas que manejan superposición entre los conjuntos de datos.  Pandas incluye funciones y métodos que hacen que este tipo de operaciones de datos seas rápidas y sencillas.
#
# En esta lección echaremos un vistazo a la concatenación con la función  ``pd.concat``.

# %% [markdown]
# # Librerías
#
# Cargando las bibliotecas que necesitamos

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# dataframe
data = {'pais': ['Belgium', 'France', 'Germany', 'Netherlands', 'United Kingdom'],
        'poblacion': [11.3, 64.3, 81.3, 16.9, 64.9],
        'area': [30510, 671308, 357050, 41526, 244820],
        'capital': ['Brussels', 'Paris', 'Berlin', 'Amsterdam', 'London']}
paises = pd.DataFrame(data)
paises
# Out:
#              pais  poblacion    area    capital
# 0         Belgium       11.3   30510   Brussels
# 1          France       64.3  671308      Paris
# 2         Germany       81.3  357050     Berlin
# 3     Netherlands       16.9   41526  Amsterdam
# 4  United Kingdom       64.9  244820     London

# %%
#Agregar la  columna de densidad poblacional
paises['densidad_poblacional'] = paises['poblacion']*1e6 / paises['area']
paises
# Out:
#              pais  poblacion    area    capital  densidad_poblacional
# 0         Belgium       11.3   30510   Brussels            370.370370
# 1          France       64.3  671308      Paris             95.783158
# 2         Germany       81.3  357050     Berlin            227.699202
# 3     Netherlands       16.9   41526  Amsterdam            406.973944
# 4  United Kingdom       64.9  244820     London            265.092721

# %% [markdown]
# # Concatenando DataFrames

# %% [markdown]
# La función ``pd.concat`` hace todo el trabajo de combinar datos de diferentes maneras. ``pd.concat`` toma una lista o diccionario de los objetos Series/DataFrame y los concatena en una cierta dirección (`axis`) con un manejo configurable de "qué hacer con los otros ejes".

# %% [markdown]
# ## Combinando filas - ``pd.concat``

# %% [markdown]
# ![](figuras/schema-concat0.svg)

# %% [markdown]
# Supongamos que tenemos algunos datos similares a los del *DataFrame paises*, pero para un conjunto de países diferentes:

# %%
data = {'pais': ['Nigeria', 'Rwanda', 'Egypt', 'Morocco', ],
        'poblacion': [182.2, 11.3, 94.3, 34.4],
        'area': [923768, 26338 , 1010408, 710850],
        'capital': ['Abuja', 'Kigali', 'Cairo', 'Rabat']}
paises_africa = pd.DataFrame(data)
paises_africa
# Out:
#       pais  poblacion     area capital
# 0  Nigeria      182.2   923768   Abuja
# 1   Rwanda       11.3    26338  Kigali
# 2    Egypt       94.3  1010408   Cairo
# 3  Morocco       34.4   710850   Rabat

# %% [markdown]
# Ahora queremos combinar las filas de ambos conjuntos de datos:

# %%
# combinar las filas
df = pd.concat([paises, paises_africa], axis=0)
df
# Out:
#              pais  poblacion     area    capital  densidad_poblacional
# 0         Belgium       11.3    30510   Brussels            370.370370
# 1          France       64.3   671308      Paris             95.783158
# 2         Germany       81.3   357050     Berlin            227.699202
# 3     Netherlands       16.9    41526  Amsterdam            406.973944
# 4  United Kingdom       64.9   244820     London            265.092721
# 0         Nigeria      182.2   923768      Abuja                   NaN
# 1          Rwanda       11.3    26338     Kigali                   NaN
# 2           Egypt       94.3  1010408      Cairo                   NaN
# 3         Morocco       34.4   710850      Rabat                   NaN

# %% [markdown]
# Se puede observar que pudiera existir una confusión por los índices repetidos, también que cuando los *DataFrame*  no tienen el mismo conjunto de columnas, por defecto se introducen. Si no queremos que se conserve el índice:

# %%
# ignorando el indice
df = pd.concat([paises, paises_africa], axis = 0, ignore_index = True)
df
# Out:
#              pais  poblacion     area    capital  densidad_poblacional
# 0         Belgium       11.3    30510   Brussels            370.370370
# 1          France       64.3   671308      Paris             95.783158
# 2         Germany       81.3   357050     Berlin            227.699202
# 3     Netherlands       16.9    41526  Amsterdam            406.973944
# 4  United Kingdom       64.9   244820     London            265.092721
# 5         Nigeria      182.2   923768      Abuja                   NaN
# 6          Rwanda       11.3    26338     Kigali                   NaN
# 7           Egypt       94.3  1010408      Cairo                   NaN
# 8         Morocco       34.4   710850      Rabat                   NaN

# %% [markdown]
# ## Combinando columnas - ``pd.concat`` con `` axis = 1``

# %% [markdown]
# ![](figuras/schema-concat1.svg)

# %% [markdown]
# Supongamos que tenemos otro DataFrame para los mismos países, pero con algunas estadísticas adicionales:

# %%
data = {'pais': ['Belgium', 'France', 'Netherlands'],
        'GDP': [496477, 2650823, 820726],
        'C02': [8.0, 9.9, 5.7]}

# %%
# Crear el dataframe paises_economics
paises_economics = pd.DataFrame(data)
paises_economics
# Out:
#           pais      GDP  C02
# 0      Belgium   496477  8.0
# 1       France  2650823  9.9
# 2  Netherlands   820726  5.7

# %%
# Concatenar 
df = pd.concat([df, paises_economics], axis = 1)
df
# Out:
#              pais  poblacion     area    capital  densidad_poblacional  \
# 0         Belgium       11.3    30510   Brussels            370.370370
# 1          France       64.3   671308      Paris             95.783158
# 2         Germany       81.3   357050     Berlin            227.699202
# 3     Netherlands       16.9    41526  Amsterdam            406.973944
# 4  United Kingdom       64.9   244820     London            265.092721
# 5         Nigeria      182.2   923768      Abuja                   NaN
# 6          Rwanda       11.3    26338     Kigali                   NaN
# 7           Egypt       94.3  1010408      Cairo                   NaN
# 8         Morocco       34.4   710850      Rabat                   NaN
#
#           pais        GDP  C02
# 0      Belgium   496477.0  8.0
# 1       France  2650823.0  9.9
# 2  Netherlands   820726.0  5.7
# 3          NaN        NaN  NaN
# 4          NaN        NaN  NaN
# 5          NaN        NaN  NaN
# 6          NaN        NaN  NaN
# 7          NaN        NaN  NaN
# 8          NaN        NaN  NaN

# %% [markdown]
# Como se observa la concatenación fue correcta pero los datos no coinciden con los países , `pd.concat` puede hace coincidir los diferentes objetos basados con el índice:

# %%
#Colocaremos la columna 'pais' como índice
df = pd.concat([paises, paises_africa], axis = 0, ignore_index = True)
df = df.set_index('pais')
df
# Out:
#                 poblacion     area    capital  densidad_poblacional
# pais
# Belgium              11.3    30510   Brussels            370.370370
# France               64.3   671308      Paris             95.783158
# Germany              81.3   357050     Berlin            227.699202
# Netherlands          16.9    41526  Amsterdam            406.973944
# United Kingdom       64.9   244820     London            265.092721
# Nigeria             182.2   923768      Abuja                   NaN
# Rwanda               11.3    26338     Kigali                   NaN
# Egypt                94.3  1010408      Cairo                   NaN
# Morocco              34.4   710850      Rabat                   NaN

# %%
#Colocaremos la columna 'pais' como índice
paises_economics = paises_economics.set_index('pais')
paises_economics
# Out:
#                  GDP  C02
# pais
# Belgium       496477  8.0
# France       2650823  9.9
# Netherlands   820726  5.7

# %%
# Concatenando
df = pd.concat([df, paises_economics], axis = 1)
df
# Out:
#                 poblacion     area    capital  densidad_poblacional  \
# pais
# Belgium              11.3    30510   Brussels            370.370370
# France               64.3   671308      Paris             95.783158
# Germany              81.3   357050     Berlin            227.699202
# Netherlands          16.9    41526  Amsterdam            406.973944
# United Kingdom       64.9   244820     London            265.092721
# Nigeria             182.2   923768      Abuja                   NaN
# Rwanda               11.3    26338     Kigali                   NaN
# Egypt                94.3  1010408      Cairo                   NaN
# Morocco              34.4   710850      Rabat                   NaN
#
#                       GDP  C02
# pais
# Belgium          496477.0  8.0
# France          2650823.0  9.9
# Germany               NaN  NaN
# Netherlands      820726.0  5.7
# United Kingdom        NaN  NaN
# Nigeria               NaN  NaN
# Rwanda                NaN  NaN
# Egypt                 NaN  NaN
# Morocco               NaN  NaN

# %% [markdown]
# ## Uniendo datos con `pd.merge`

# %% [markdown]
# Usando `pd.concat` arriba, combinamos conjuntos de datos que tenían las mismas columnas o los mismos valores de índice. Pero, otro caso típico es si desea agregar información del segundo *DataFrame* a un primero basado en una de las columnas. Eso se puede hacer con `pd.merge` (http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.merge.html).
#
# Veamos nuevamente los datos del Titanic, pero tomemos un pequeño subconjunto para hacer que el ejemplo sea más fácil de entender:

# %%
df = pd.read_csv("datos/titanic.csv")
df = df.loc[:9, ['Survived', 'Pclass', 'Sex', 'Age', 'Fare', 'Embarked']]

# %%
# mostrar las primeras filas de df
df.head()
# Out:
#    Survived  Pclass     Sex   Age     Fare Embarked
# 0         0       3    male  22.0   7.2500        S
# 1         1       1  female  38.0  71.2833        C
# 2         1       3  female  26.0   7.9250        S
# 3         1       1  female  35.0  53.1000        S
# 4         0       3    male  35.0   8.0500        S

# %% [markdown]
# Supongamos que tenemos otro *DataFrame* con más información sobre las ubicaciones de embarque:

# %%
localidades = pd.DataFrame({'Embarked': ['S', 'C', 'Q', 'N'],
                          'City': ['Southampton', 'Cherbourg', 'Queenstown', 'New York City'],
                          'Country': ['United Kindom', 'France', 'Ireland', 'United States']})
localidades
# Out:
#   Embarked           City        Country
# 0        S    Southampton  United Kindom
# 1        C      Cherbourg         France
# 2        Q     Queenstown        Ireland
# 3        N  New York City  United States

# %% [markdown]
# Ahora queremos agregar esas columnas al DataFrame del Titanic, para lo cual podemos usar `pd.merge`, especificando la columna en la que queremos fusionar los dos conjuntos de datos:

# %%
# Utilizar 'Embarked'
df = pd.merge(df, localidades, on = 'Embarked')
df
# Out:
#    Survived  Pclass     Sex   Age     Fare Embarked         City  \
# 0         0       3    male  22.0   7.2500        S  Southampton
# 1         1       3  female  26.0   7.9250        S  Southampton
# 2         1       1  female  35.0  53.1000        S  Southampton
# 3         0       3    male  35.0   8.0500        S  Southampton
# 4         0       1    male  54.0  51.8625        S  Southampton
# 5         0       3    male   2.0  21.0750        S  Southampton
# 6         1       3  female  27.0  11.1333        S  Southampton
# 7         1       1  female  38.0  71.2833        C    Cherbourg
# 8         1       2  female  14.0  30.0708        C    Cherbourg
# 9         0       3    male   NaN   8.4583        Q   Queenstown
#
#          Country
# 0  United Kindom
# 1  United Kindom
# 2  United Kindom
# 3  United Kindom
# 4  United Kindom
# 5  United Kindom
# 6  United Kindom
# 7         France
# 8         France
# 9        Ireland

# %% [markdown]
# ## Ejercicios - parte A

# %% [markdown]
# <div class="alert alert-success">
#
# <b>EJERCICIO 1</b>:
#
# Tomando los siguientes *DataFrames* encontrar la salida que se muestra en la imagen
#
# df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
#                     'B': ['B0', 'B1', 'B2', 'B3'],
#                     'C': ['C0', 'C1', 'C2', 'C3'],
#                     'D': ['D0', 'D1', 'D2', 'D3']})
#
# df2 = pd.DataFrame({'A': ['A4', 'A5', 'A6', 'A7'],
#                     'B': ['B4', 'B5', 'B6', 'B7'],
#                     'C': ['C4', 'C5', 'C6', 'C7'],
#                     'D': ['D4', 'D5', 'D6', 'D7']})
#
# df3 = pd.DataFrame({'A': ['A8', 'A9', 'A10', 'A11'],
#                     'B': ['B8', 'B9', 'B10', 'B11'],
#                     'C': ['C8', 'C9', 'C10', 'C11'],
#                     'D': ['D8', 'D9', 'D10', 'D11']})
#
#
# **Salida**:
#
# <img align="left" width="150"  float= "none" align="middle" src="figuras/concat_1.png">
#
#
# </div>

# %%
# Creación de los DataFrames
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'], 'B': ['B0', 'B1', 'B2', 'B3'], 'C': ['C0', 'C1', 'C2', 'C3'], 'D': ['D0', 'D1', 'D2', 'D3']})
df2 = pd.DataFrame({'A': ['A4', 'A5', 'A6', 'A7'], 'B': ['B4', 'B5', 'B6', 'B7'], 'C': ['C4', 'C5', 'C6', 'C7'], 'D': ['D4', 'D5', 'D6', 'D7']})
df3 = pd.DataFrame({'A': ['A8', 'A9', 'A10', 'A11'], 'B': ['B8', 'B9', 'B10', 'B11'], 'C': ['C8', 'C9', 'C10', 'C11'], 'D': ['D8', 'D9', 'D10', 'D11']})

# %%
df1
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
df2
# Out:
#     A   B   C   D
# 0  A4  B4  C4  D4
# 1  A5  B5  C5  D5
# 2  A6  B6  C6  D6
# 3  A7  B7  C7  D7

# %%
df3
# Out:
#      A    B    C    D
# 0   A8   B8   C8   D8
# 1   A9   B9   C9   D9
# 2  A10  B10  C10  D10
# 3  A11  B11  C11  D11

# %%
pd.concat([df1, df2, df3], ignore_index=True)
# Out:
#       A    B    C    D
# 0    A0   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C2   D2
# 3    A3   B3   C3   D3
# 4    A4   B4   C4   D4
# 5    A5   B5   C5   D5
# 6    A6   B6   C6   D6
# 7    A7   B7   C7   D7
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %% [markdown]
# <div class="alert alert-success">
#
# <b>EJERCICIO 2</b>:
#
# Tomando los *DataFrames*  df1 y df4, encontrar la salida que se muestra en la imagen
#
# df4 = pd.DataFrame({'B': ['B2', 'B3', 'B6', 'B7'],
#                     'D': ['D2', 'D3', 'D6', 'D7'],
#                     'F': ['F2', 'F3', 'F6', 'F7']},
#                    index=[2, 3, 6, 7])
#
# **Salida**:
#
# <img align="left" width="250"  float= "none" align="middle" src="figuras/concat_1b.png">
#
#
# </div>

# %%
# Creación del DataFrame
df4 = pd.DataFrame({'B': ['B2', 'B3', 'B6', 'B7'], 'D': ['D2', 'D3', 'D6', 'D7'], 'F': ['F2', 'F3', 'F6', 'F7']}, index=[2, 3, 6, 7])
df4
# Out:
#     B   D   F
# 2  B2  D2  F2
# 3  B3  D3  F3
# 6  B6  D6  F6
# 7  B7  D7  F7

# %%
pd.concat([df1, df4], axis=1)
# Out:
#      A    B    C    D    B    D    F
# 0   A0   B0   C0   D0  NaN  NaN  NaN
# 1   A1   B1   C1   D1  NaN  NaN  NaN
# 2   A2   B2   C2   D2   B2   D2   F2
# 3   A3   B3   C3   D3   B3   D3   F3
# 6  NaN  NaN  NaN  NaN   B6   D6   F6
# 7  NaN  NaN  NaN  NaN   B7   D7   F7

# %% [markdown]
# <div class="alert alert-success">
#
# <b>EJERCICIO 3</b>:
#
# Tomando los siguientes *DataFrames* encontrar la salida que se muestra en la imagen
#
# left = pd.DataFrame({'Key': ['K0', 'K1', 'K2', 'K3'],
#                     'A': ['A0', 'A1', 'A2', 'A3'],
#                     'B': ['B0', 'B1', 'B2', 'B3']})
#
# right = pd.DataFrame({'Key': ['K0', 'K1', 'K2', 'K3'],
#                       'C': ['C0', 'C1', 'C2', 'C3'],
#                       'D': ['D0', 'D1', 'D2', 'D3']})
#
# **Salida**:
#
# <img align="left" width="150"  float= "none" align="middle" src="figuras/concat_2.png">
#
#
# </div>

# %%
# Creación de los DataFrames
left = pd.DataFrame({'Key': ['K0', 'K1', 'K2', 'K3'], 'A': ['A0', 'A1', 'A2', 'A3'], 'B': ['B0', 'B1', 'B2', 'B3']})
right = pd.DataFrame({'Key': ['K0', 'K1', 'K2', 'K3'], 'C': ['C0', 'C1', 'C2', 'C3'], 'D': ['D0', 'D1', 'D2', 'D3']})

# %%
left
# Out:
#   Key   A   B
# 0  K0  A0  B0
# 1  K1  A1  B1
# 2  K2  A2  B2
# 3  K3  A3  B3

# %%
right
# Out:
#   Key   C   D
# 0  K0  C0  D0
# 1  K1  C1  D1
# 2  K2  C2  D2
# 3  K3  C3  D3

# %%
pd.merge(left, right, on='Key')
# Out:
#   Key   A   B   C   D
# 0  K0  A0  B0  C0  D0
# 1  K1  A1  B1  C1  D1
# 2  K2  A2  B2  C2  D2
# 3  K3  A3  B3  C3  D3

# %% [markdown]
# # Ejercicios - parte B

# %% [markdown]
# Utilizar los datos de north_america_2000_2010.csv y  south_america_2000_2010.csv que corresponden a información de los años 2000 al 2010,para los países de México, Canadá, Estados Unidos y Chile

# %%
north_america = pd.read_csv('datos/north_america_2000_2010.csv', index_col=0)
north_america
# Out:
#            2000    2001    2002    2003    2004  2005    2006    2007  2008  \
# Country
# Canada   1779.0  1771.0  1754.0  1740.0  1760.0  1747  1745.0  1741.0  1735
# Mexico   2311.2  2285.2  2271.2  2276.5  2270.6  2281  2280.6  2261.4  2258
# USA      1836.0  1814.0  1810.0  1800.0  1802.0  1799  1800.0  1798.0  1792
#
#            2009    2010
# Country
# Canada   1701.0  1703.0
# Mexico   2250.2  2242.4
# USA      1767.0  1778.0

# %%
south_america = pd.read_csv('datos/south_america_2000_2010.csv', index_col=0)
south_america
# Out:
#          2000  2001  2002  2003  2004  2005  2006  2007  2008  2009    2010
# Country
# Chile    2263  2242  2250  2235  2232  2157  2165  2128  2095  2074  2069.6

# %% [markdown]
# <div class="alert alert-success">
#
# <b>EJERCICIO 4</b>:
#
# Tomando los   *DataFrames* north_america y  south_america encontrar la salida que se muestra en la imagen
#
# **Salida**:
#
# <img align="left" width="550"  float= "none" align="middle" src="figuras/ejercicioB1.png">
#
#
# </div>

# %%
america = pd.concat([north_america, south_america])
america
# Out:
#            2000    2001    2002    2003    2004  2005    2006    2007  2008  \
# Country
# Canada   1779.0  1771.0  1754.0  1740.0  1760.0  1747  1745.0  1741.0  1735
# Mexico   2311.2  2285.2  2271.2  2276.5  2270.6  2281  2280.6  2261.4  2258
# USA      1836.0  1814.0  1810.0  1800.0  1802.0  1799  1800.0  1798.0  1792
# Chile    2263.0  2242.0  2250.0  2235.0  2232.0  2157  2165.0  2128.0  2095
#
#            2009    2010
# Country
# Canada   1701.0  1703.0
# Mexico   2250.2  2242.4
# USA      1767.0  1778.0
# Chile    2074.0  2069.6

# %% [markdown]
# <div class="alert alert-success">
#
# <b>EJERCICIO 5</b>:
#
# Queremos que nuestros datos sean lo más recientes posible. Después de solicitar datos sobre estos cuatro países de años posteriores, el equipo de recopilación de datos  envió cada año desde 2011 hasta 2015 en archivos CSV separados de la siguiente manera americas_2011.csv , americas_2012.csv, americas_2013.csv,americas_2014.csv, americas_2015.csv:
#
# **Salida**:
#
# <img align="left" width="750"  float= "none" align="middle" src="figuras/ejercicioB-3.png">
#
#
# </div>

# %%
america_actualizacion  = pd.concat([
    pd.read_csv('datos/americas_2011.csv', index_col=0),
    pd.read_csv('datos/americas_2012.csv', index_col=0),
    pd.read_csv('datos/americas_2013.csv', index_col=0),
    pd.read_csv('datos/americas_2014.csv', index_col=0),
    pd.read_csv('datos/americas_2015.csv', index_col=0)], axis = 1)
america_actualizacion
# Out:
#            2011    2012    2013    2014    2015
# Country
# Canada   1700.0  1713.0  1707.0  1703.0  1706.0
# Chile    2047.4  2024.0  2015.3  1990.1  1987.5
# Mexico   2250.2  2225.8  2236.6  2228.4  2246.4
# USA      1786.0  1789.0  1787.0  1789.0  1790.0

# %%
america = pd.concat([america, america_actualizacion], axis=1)
america
# Out:
#            2000    2001    2002    2003    2004  2005    2006    2007  2008  \
# Country
# Canada   1779.0  1771.0  1754.0  1740.0  1760.0  1747  1745.0  1741.0  1735
# Mexico   2311.2  2285.2  2271.2  2276.5  2270.6  2281  2280.6  2261.4  2258
# USA      1836.0  1814.0  1810.0  1800.0  1802.0  1799  1800.0  1798.0  1792
# Chile    2263.0  2242.0  2250.0  2235.0  2232.0  2157  2165.0  2128.0  2095
#
#            2009    2010    2011    2012    2013    2014    2015
# Country
# Canada   1701.0  1703.0  1700.0  1713.0  1707.0  1703.0  1706.0
# Mexico   2250.2  2242.4  2250.2  2225.8  2236.6  2228.4  2246.4
# USA      1767.0  1778.0  1786.0  1789.0  1787.0  1789.0  1790.0
# Chile    2074.0  2069.6  2047.4  2024.0  2015.3  1990.1  1987.5

# %% [markdown]
# <div class="alert alert-success">
#
# <b>EJERCICIO 6</b>:
#
# Ahora que tenemos una vista completa de las Américas, nos gustaría ver cómo se compara con el resto del mundo. El equipo de recopilación de datos ha proporcionado archivos CSV para Asia, Europa y el Pacífico Sur desde 2000 hasta 2015. Utilizar los archivos asia_2000_2015.csv, europe_2000_2015.csv y south_pacific_2000_2015.csv
#
# Encontrar la salida que se muestra en la imagen
#
# **Salida**:
# *Solo se muestran unas cuantas filas
#
#
# <img align="left" width="750"  float= "none" align="middle" src="figuras/ejercicioC.png">
#
#
# </div>

# %%
asia = pd.read_csv('datos/asia_2000_2015.csv', index_col=0)
asia
# Out:
#          2000  2001  2002  2003  2004  2005  2006  2007  2008  2009  2010  \
# Country
# Israel   2017  1979  1993  1974  1942  1931  1919  1931  1929  1927  1918
# Japan    1821  1809  1798  1799  1787  1775  1784  1785  1771  1714  1733
# Korea    2512  2499  2464  2424  2392  2351  2346  2306  2246  2232  2187
# Russia   1982  1980  1982  1993  1993  1989  1998  1999  1997  1974  1976
#
#          2011  2012  2013  2014  2015
# Country
# Israel   1920  1910  1867  1853  1858
# Japan    1728  1745  1734  1729  1719
# Korea    2090  2163  2079  2124  2113
# Russia   1979  1982  1980  1985  1978

# %%
europe = pd.read_csv('datos/europe_2000_2015.csv', index_col=0)
europe
# Out:
#                  2000  2001  2002  2003  2004  2005  2006  2007  2008  2009  \
# Country
# Austria          1807  1795  1792  1784  1787  1764  1746  1736  1729  1673
# Belgium          1595  1588  1583  1578  1573  1565  1572  1577  1570  1548
# Switzerland      1674  1635  1614  1627  1657  1652  1643  1633  1623  1615
# Czech Republic   1896  1818  1816  1806  1817  1817  1799  1784  1790  1779
# Germany          1452  1442  1431  1425  1422  1411  1425  1424  1418  1373
# Denmark          1490  1493  1487  1482  1481  1474  1479  1456  1450  1446
# Spain            1753  1763  1765  1756  1742  1726  1716  1704  1713  1720
# Estonia          1978  1970  1973  1978  1986  2008  2001  1998  1968  1831
# Finland          1742  1723  1714  1705  1707  1697  1693  1691  1685  1661
# France           1535  1526  1487  1484  1513  1507  1484  1500  1507  1489
# United Kingdom   1700  1705  1684  1674  1674  1673  1669  1677  1659  1651
# Greece           2108  2101  2093  2091  2083  2136  2125  2111  2106  2081
# Hungary          2033  1993  2005  1978  1986  1987  1984  1979  1982  1963
# Ireland          1933  1924  1904  1887  1875  1883  1879  1865  1844  1812
# Iceland          2040  2053  2012  1972  1980  1970  1958  1932  1934  1849
# Italy            1851  1838  1827  1816  1815  1812  1813  1818  1807  1776
# Lithuania        1846  1831  1802  1786  1879  1879  1874  1904  1934  1863
# Luxembourg       1603  1586  1581  1579  1579  1555  1556  1570  1570  1519
# Latvia           1976  1987  1938  1928  1878  1906  1907  1878  2002  1952
# Netherlands      1462  1452  1435  1427  1448  1434  1430  1430  1430  1422
# Norway           1455  1429  1414  1401  1421  1423  1420  1426  1430  1407
# Poland           1988  1974  1979  1984  1983  1994  1985  1976  1969  1948
# Portugal         1917  1900  1894  1887  1893  1895  1883  1900  1887  1887
# Slovak Republic  1816  1801  1754  1698  1742  1769  1774  1791  1793  1780
# Slovenia         1710  1696  1721  1724  1737  1697  1667  1655  1674  1679
# Sweden           1642  1618  1595  1582  1605  1605  1599  1612  1617  1609
#
#                  2010  2011  2012  2013  2014  2015
# Country
# Austria          1669  1676  1653  1637  1629  1625
# Belgium          1546  1560  1560  1558  1560  1541
# Switzerland      1612  1605  1591  1573  1568  1590
# Czech Republic   1800  1806  1776  1763  1771  1779
# Germany          1390  1393  1375  1362  1366  1371
# Denmark          1436  1455  1437  1457  1458  1457
# Spain            1710  1716  1700  1696  1698  1691
# Estonia          1875  1919  1886  1866  1859  1852
# Finland          1668  1662  1650  1640  1643  1646
# France           1494  1496  1490  1474  1473  1482
# United Kingdom   1650  1634  1654  1666  1677  1674
# Greece           2020  2038  2055  2063  2026  2042
# Hungary          1958  1976  1889  1880  1858  1749
# Ireland          1801  1801  1806  1815  1821  1820
# Iceland          1834  1878  1853  1846  1864  1880
# Italy            1777  1773  1734  1720  1719  1725
# Lithuania        1884  1859  1857  1841  1834  1860
# Luxembourg       1521  1519  1513  1503  1509  1507
# Latvia           1935  1952  1934  1928  1938  1903
# Netherlands      1421  1422  1413  1415  1420  1419
# Norway           1415  1421  1420  1408  1427  1424
# Poland           1940  1938  1929  1918  1923  1963
# Portugal         1890  1867  1849  1859  1865  1868
# Slovak Republic  1805  1793  1789  1772  1760  1754
# Slovenia         1680  1663  1636  1655  1676  1676
# Sweden           1635  1632  1618  1609  1611  1612

# %%
south_pacific = pd.read_csv('datos/south_pacific_2000_2015.csv', index_col=0)
south_pacific
# Out:
#                2000    2001    2002    2003    2004    2005    2006    2007  \
# Country
# Australia    1778.7  1736.7  1731.7  1735.8  1734.5  1729.2  1720.5  1712.5
# New Zealand  1836.0  1825.0  1826.0  1823.0  1830.0  1815.0  1795.0  1774.0
#
#                2008  2009    2010    2011    2012    2013    2014  2015
# Country
# Australia    1717.2  1690  1691.5  1699.5  1678.6  1662.7  1663.6  1665
# New Zealand  1761.0  1740  1755.0  1746.0  1734.0  1752.0  1762.0  1757

# %%
# pd.concat([america, asia, europe, south_pacific], axis=0)
pd.concat([america, asia, europe, south_pacific])
# Out:
#                    2000    2001    2002    2003    2004    2005    2006  \
# Country
# Canada           1779.0  1771.0  1754.0  1740.0  1760.0  1747.0  1745.0
# Mexico           2311.2  2285.2  2271.2  2276.5  2270.6  2281.0  2280.6
# USA              1836.0  1814.0  1810.0  1800.0  1802.0  1799.0  1800.0
# Chile            2263.0  2242.0  2250.0  2235.0  2232.0  2157.0  2165.0
# Israel           2017.0  1979.0  1993.0  1974.0  1942.0  1931.0  1919.0
# Japan            1821.0  1809.0  1798.0  1799.0  1787.0  1775.0  1784.0
# Korea            2512.0  2499.0  2464.0  2424.0  2392.0  2351.0  2346.0
# Russia           1982.0  1980.0  1982.0  1993.0  1993.0  1989.0  1998.0
# Austria          1807.0  1795.0  1792.0  1784.0  1787.0  1764.0  1746.0
# Belgium          1595.0  1588.0  1583.0  1578.0  1573.0  1565.0  1572.0
# Switzerland      1674.0  1635.0  1614.0  1627.0  1657.0  1652.0  1643.0
# Czech Republic   1896.0  1818.0  1816.0  1806.0  1817.0  1817.0  1799.0
# Germany          1452.0  1442.0  1431.0  1425.0  1422.0  1411.0  1425.0
# Denmark          1490.0  1493.0  1487.0  1482.0  1481.0  1474.0  1479.0
# Spain            1753.0  1763.0  1765.0  1756.0  1742.0  1726.0  1716.0
# Estonia          1978.0  1970.0  1973.0  1978.0  1986.0  2008.0  2001.0
# Finland          1742.0  1723.0  1714.0  1705.0  1707.0  1697.0  1693.0
# France           1535.0  1526.0  1487.0  1484.0  1513.0  1507.0  1484.0
# United Kingdom   1700.0  1705.0  1684.0  1674.0  1674.0  1673.0  1669.0
# Greece           2108.0  2101.0  2093.0  2091.0  2083.0  2136.0  2125.0
# Hungary          2033.0  1993.0  2005.0  1978.0  1986.0  1987.0  1984.0
# Ireland          1933.0  1924.0  1904.0  1887.0  1875.0  1883.0  1879.0
# Iceland          2040.0  2053.0  2012.0  1972.0  1980.0  1970.0  1958.0
# Italy            1851.0  1838.0  1827.0  1816.0  1815.0  1812.0  1813.0
# Lithuania        1846.0  1831.0  1802.0  1786.0  1879.0  1879.0  1874.0
# Luxembourg       1603.0  1586.0  1581.0  1579.0  1579.0  1555.0  1556.0
# Latvia           1976.0  1987.0  1938.0  1928.0  1878.0  1906.0  1907.0
# Netherlands      1462.0  1452.0  1435.0  1427.0  1448.0  1434.0  1430.0
# Norway           1455.0  1429.0  1414.0  1401.0  1421.0  1423.0  1420.0
# Poland           1988.0  1974.0  1979.0  1984.0  1983.0  1994.0  1985.0
# Portugal         1917.0  1900.0  1894.0  1887.0  1893.0  1895.0  1883.0
# Slovak Republic  1816.0  1801.0  1754.0  1698.0  1742.0  1769.0  1774.0
# Slovenia         1710.0  1696.0  1721.0  1724.0  1737.0  1697.0  1667.0
# Sweden           1642.0  1618.0  1595.0  1582.0  1605.0  1605.0  1599.0
# Australia        1778.7  1736.7  1731.7  1735.8  1734.5  1729.2  1720.5
# New Zealand      1836.0  1825.0  1826.0  1823.0  1830.0  1815.0  1795.0
#
#                    2007    2008    2009    2010    2011    2012    2013  \
# Country
# Canada           1741.0  1735.0  1701.0  1703.0  1700.0  1713.0  1707.0
# Mexico           2261.4  2258.0  2250.2  2242.4  2250.2  2225.8  2236.6
# USA              1798.0  1792.0  1767.0  1778.0  1786.0  1789.0  1787.0
# Chile            2128.0  2095.0  2074.0  2069.6  2047.4  2024.0  2015.3
# Israel           1931.0  1929.0  1927.0  1918.0  1920.0  1910.0  1867.0
# Japan            1785.0  1771.0  1714.0  1733.0  1728.0  1745.0  1734.0
# Korea            2306.0  2246.0  2232.0  2187.0  2090.0  2163.0  2079.0
# Russia           1999.0  1997.0  1974.0  1976.0  1979.0  1982.0  1980.0
# Austria          1736.0  1729.0  1673.0  1669.0  1676.0  1653.0  1637.0
# Belgium          1577.0  1570.0  1548.0  1546.0  1560.0  1560.0  1558.0
# Switzerland      1633.0  1623.0  1615.0  1612.0  1605.0  1591.0  1573.0
# Czech Republic   1784.0  1790.0  1779.0  1800.0  1806.0  1776.0  1763.0
# Germany          1424.0  1418.0  1373.0  1390.0  1393.0  1375.0  1362.0
# Denmark          1456.0  1450.0  1446.0  1436.0  1455.0  1437.0  1457.0
# Spain            1704.0  1713.0  1720.0  1710.0  1716.0  1700.0  1696.0
# Estonia          1998.0  1968.0  1831.0  1875.0  1919.0  1886.0  1866.0
# Finland          1691.0  1685.0  1661.0  1668.0  1662.0  1650.0  1640.0
# France           1500.0  1507.0  1489.0  1494.0  1496.0  1490.0  1474.0
# United Kingdom   1677.0  1659.0  1651.0  1650.0  1634.0  1654.0  1666.0
# Greece           2111.0  2106.0  2081.0  2020.0  2038.0  2055.0  2063.0
# Hungary          1979.0  1982.0  1963.0  1958.0  1976.0  1889.0  1880.0
# Ireland          1865.0  1844.0  1812.0  1801.0  1801.0  1806.0  1815.0
# Iceland          1932.0  1934.0  1849.0  1834.0  1878.0  1853.0  1846.0
# Italy            1818.0  1807.0  1776.0  1777.0  1773.0  1734.0  1720.0
# Lithuania        1904.0  1934.0  1863.0  1884.0  1859.0  1857.0  1841.0
# Luxembourg       1570.0  1570.0  1519.0  1521.0  1519.0  1513.0  1503.0
# Latvia           1878.0  2002.0  1952.0  1935.0  1952.0  1934.0  1928.0
# Netherlands      1430.0  1430.0  1422.0  1421.0  1422.0  1413.0  1415.0
# Norway           1426.0  1430.0  1407.0  1415.0  1421.0  1420.0  1408.0
# Poland           1976.0  1969.0  1948.0  1940.0  1938.0  1929.0  1918.0
# Portugal         1900.0  1887.0  1887.0  1890.0  1867.0  1849.0  1859.0
# Slovak Republic  1791.0  1793.0  1780.0  1805.0  1793.0  1789.0  1772.0
# Slovenia         1655.0  1674.0  1679.0  1680.0  1663.0  1636.0  1655.0
# Sweden           1612.0  1617.0  1609.0  1635.0  1632.0  1618.0  1609.0
# Australia        1712.5  1717.2  1690.0  1691.5  1699.5  1678.6  1662.7
# New Zealand      1774.0  1761.0  1740.0  1755.0  1746.0  1734.0  1752.0
#
#                    2014    2015
# Country
# Canada           1703.0  1706.0
# Mexico           2228.4  2246.4
# USA              1789.0  1790.0
# Chile            1990.1  1987.5
# Israel           1853.0  1858.0
# Japan            1729.0  1719.0
# Korea            2124.0  2113.0
# Russia           1985.0  1978.0
# Austria          1629.0  1625.0
# Belgium          1560.0  1541.0
# Switzerland      1568.0  1590.0
# Czech Republic   1771.0  1779.0
# Germany          1366.0  1371.0
# Denmark          1458.0  1457.0
# Spain            1698.0  1691.0
# Estonia          1859.0  1852.0
# Finland          1643.0  1646.0
# France           1473.0  1482.0
# United Kingdom   1677.0  1674.0
# Greece           2026.0  2042.0
# Hungary          1858.0  1749.0
# Ireland          1821.0  1820.0
# Iceland          1864.0  1880.0
# Italy            1719.0  1725.0
# Lithuania        1834.0  1860.0
# Luxembourg       1509.0  1507.0
# Latvia           1938.0  1903.0
# Netherlands      1420.0  1419.0
# Norway           1427.0  1424.0
# Poland           1923.0  1963.0
# Portugal         1865.0  1868.0
# Slovak Republic  1760.0  1754.0
# Slovenia         1676.0  1676.0
# Sweden           1611.0  1612.0
# Australia        1663.6  1665.0
# New Zealand      1762.0  1757.0
